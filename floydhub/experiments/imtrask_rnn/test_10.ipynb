# %%
for i in range(binary_dim):
    X = np.array([[a[i], b[i]]])
    
    layer_1 = layer_1_values[-i-1]
    prev_layer_1 = layer_1_values[-i-2]
    
    layer_2_delta = layer_2_deltas[-i-1]
    layer_1_delta = (future_layer_1.dot(synapse_h.T) + layer_2_delta.dot(synapse_1) * s_t_d(layer_1))
    
    synapse_1_udate = np.atleast_2D(layer_1.dot(layer_2_delta))
    synapse_h_update = np.atleast_2D(prev_layer_1.dot(layer_1_delta))
    synapse_0_update = np.atleast_2D(X.dot.T(synapse_0))
