# %%
"""
Minimal character-level Vanilla RNN model. Written by Andrej Karpathy (@karpathy)
BSD License
"""
import numpy as np

# data I/O
data = open('input.txt', 'r').read() # should be simple plain text file
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print('data has %d characters, %d unique.' % (data_size, vocab_size))
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }

# hyperparameters
hidden_size = 100 # size of hidden layer of neurons
seq_length = 25 # number of steps to unroll the RNN for
learning_rate = 1e-1

# model parameters
Wxh = np.random.randn(hidden_size, vocab_size)*0.01 # input to hidden
Whh = np.random.randn(hidden_size, hidden_size)*0.01 # hidden to hidden
Why = np.random.randn(vocab_size, hidden_size)*0.01 # hidden to output
bh = np.zeros((hidden_size, 1)) # hidden bias
by = np.zeros((vocab_size, 1)) # output bias

def lossFun(inputs, targets, hprev):
  """
  inputs,targets are both list of integers.
  hprev is Hx1 array of initial hidden state
  returns the loss, gradients on model parameters, and last hidden state
  """
  xs, hs, ys, ps = {}, {}, {}, {}
  hs[-1] = np.copy(hprev)
  loss = 0
  # forward pass
  for t in range(len(inputs)):
    xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
    xs[t][inputs[t]] = 1
    hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
    ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
    ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
    loss += -np.log(ps[t][targets[t],0]) # softmax (cross-entropy loss)
  # backward pass: compute gradients going backwards
  dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
  dbh, dby = np.zeros_like(bh), np.zeros_like(by)
  dhnext = np.zeros_like(hs[0])
  for t in reversed(range(len(inputs))):
    dy = np.copy(ps[t])
    dy[targets[t]] -= 1 # backprop into y. see http://cs231n.github.io/neural-networks-case-study/#grad if confused here
    dWhy += np.dot(dy, hs[t].T)
    dby += dy
    dh = np.dot(Why.T, dy) + dhnext # backprop into h
    dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
    dbh += dhraw
    dWxh += np.dot(dhraw, xs[t].T)
    dWhh += np.dot(dhraw, hs[t-1].T)
    dhnext = np.dot(Whh.T, dhraw)
  for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
    np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
  return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]

def sample(h, seed_ix, n):
  """ 
  sample a sequence of integers from the model 
  h is memory state, seed_ix is seed letter for first time step
  """
  x = np.zeros((vocab_size, 1))
  x[seed_ix] = 1
  ixes = []
  for t in range(n):
    h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
    y = np.dot(Why, h) + by
    p = np.exp(y) / np.sum(np.exp(y))
    ix = np.random.choice(range(vocab_size), p=p.ravel())
    x = np.zeros((vocab_size, 1))
    x[ix] = 1
    ixes.append(ix)
  return ixes

n, p = 0, 0
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by) # memory variables for Adagrad
smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0
while True:
  # prepare inputs (we're sweeping from left to right in steps seq_length long)
  if p+seq_length+1 >= len(data) or n == 0: 
    hprev = np.zeros((hidden_size,1)) # reset RNN memory
    p = 0 # go from start of data
  inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
  targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

  # sample from the model now and then
  if n % 100 == 0:
    sample_ix = sample(hprev, inputs[0], 200)
    txt = ''.join(ix_to_char[ix] for ix in sample_ix)
    print ('----\n %s \n----' % (txt, ))

  # forward seq_length characters through the net and fetch gradient
  loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
  smooth_loss = smooth_loss * 0.999 + loss * 0.001
  if n % 100 == 0: print ('iter %d, loss: %f' % (n, smooth_loss)) # print progress
  
  # perform parameter update with Adagrad
  for param, dparam, mem in zip([Wxh, Whh, Why, bh, by], 
                                [dWxh, dWhh, dWhy, dbh, dby], 
                                [mWxh, mWhh, mWhy, mbh, mby]):
    mem += dparam * dparam
    param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update

  p += seq_length # move data pointer
  n += 1 # iteration counter
# Out:
# data has 6903 characters, 75 unique.
# ----
#  fVzAEh1[fX_6foA/1_(/o=xvnRt-zlnNN,6faII#_E\63duboFXhgx
# Y}Iw_,_ON)"lqF{bbF5y8#Em#iGUn]Ff:,i4Y(iVE1"]yyw4h)Cay[#lu"Vzvl0-Xaexz2y_d)
# eEepriyF
# IGNmsn0/Fu=3FL1R[4S--}]y
# sdp.}/pzkaTC-fp]ivOUeOA}:I5=PFN }_N
# ----
# iter 0, loss: 107.937212
# ----
#  oprBi'pan/ddrcoi,(fao2t(nsn=##.oc=p=an"2'u5c6P=pa3o\X(ucog'(sctcs pa22 f'r{up85g3RuD3toolDmzcN r(c32 Yancy(elcoov(s3oilUun18d( 3l)  Y3,\[e#ocR,(yrc2p(p
# o  aac*]xrae)2q(tt){dp1neb"Ct
# c8A(tcoxdAeG3eD6_m
# ----
# iter 100, loss: 108.747247
# ----
#  ,nBS boc
#    onu_rd a,_ lla"h tetG   tic_X pnRe a,ia_  l,v  F mn) ane{e giay_,   U_ mgn"    g,C ttB"    "nB  s"u  4o\ez2 \o,0da)kY_ /cnfi/rir,  "a\  e Trznr CoLs g GV  esuv   brwt itSM  i ooe er ip+_"
# ----
# iter 200, loss: 106.996174
# ----
#  dArie , S"'gi_stzyo_A
# ",#e ,  :3rUo  t snnplhe_n'i "no  rL0nop4  "rPtiepo
#  .Aspm"k
# derbon
# m0.o r"3 pnntrtm,yntet"ep: "rd0Apthp  _co2bn:"eRaatprry Xu_rastnte    :oetc:n_td ecldd."onf"ec""phi6tto tgfepi
# ----
# iter 300, loss: 105.050340
# ----
#  er)=o_idtnn6 fapacpteo=ApGc
# xe\
# ,t,    pio,dot\p*o'ncts2otr5ttt  Anpnsinf_isetu'at ex  ,t2 y\pe"o,elen"}q"cpac"a\tst6m
#   "_nrldDD,
#  ri[ w"uissa,"
#    i n1   3 "
#  "\iia 2,
#
#  Cpc',opcDX)tgfd"mpu
#
# ----
# iter 400, loss: 102.944739
# ----
#  b cilra,tli_pti]o=t/",r_e__b_ao,iio,,2,
#     ":_i=e",eoeaaio": srh\igo\"" t  "#moougisd n",
#   :,{  "
#   m
# ": e_Uatuyc ntnp 2,
#   "tibd=,
#
#   d ",
# {
#  p\cdamted==u=CRnge  nn.""-teouk= \,\nd
#     ] ,
#
#
#   eU
# ----
# iter 500, loss: 100.207907
# ----
#  esloamce")
#  couroouaragt: gs},
#
#       {
#  "
#   ii,
#   "i\kprp:
#       cto,
#   "z  "r erpm
#         :
#     " , "r*cart.1gtmkprirtmp_ckeecssr )m        IDeorexblomapnf_o2oprtoutrore:"t  iif_ "v
# "ram ",erm
# ----
# iter 600, loss: 97.787300
# ----
#  riod', n=Vci)]iCiSv',o\grrod n(e,Gao.aueronpit6lu''on=pCodd]d(-ad  "rsrsareXiTup#Somehr)mecon eeiev\Ci",ecuu=Rxonpd_ing2Iintpuod n  =\=,(1,d':]ad'ctrlutpmecspden": ',",= ',
#   = 3mersud_uoutpuovat'oaat
# ----
# iter 700, loss: 95.012139
# ----
#   l= 1our(22acabgerimeaRomeppse"urucomedbr.gbD:)/ro.)rg)ct,iron_ " ",)2rsdeinalao     mo    ",
# 2 u'cteutaoodercinl"ytiie1,
#  =
#   " gin" ",
#   ",iuty_iyipao, ",od_me",
#  ":, ", gYbe\[aooutlo5e([:  Iraodein
# ----
# iter 800, loss: 92.269585
# ----
#  . pat.ih_trl min:elt":epurerea",
#
#   "
#
#   M"dan"iy2D_Tan":        "kesmmalosoitye)oincutat ve sapn"uma=eS)ipphepy}ua__lone": gmd:encut riargan:\n"fum",soralely_ot\"     ron"Frneman",
#    "",
#     "
# ----
# iter 900, loss: 90.041756
# ----
#  o3(/3((leC([
#      "r_on", ",
# )   *": cxpdearslurcut(el't*= ybzoriyo, {er_de4le
# 25)"rsdererdepud_re,
#     e= i_csiGtey(Inh(5zcsludgabzerai9enggD,{r(', atuD))9d sit_ous_u(k'nemin", s2sccegeu, 2(z vltar+b
# ----
# iter 1000, loss: 87.060701
# ----
#       "adesim",: p._n= n":
#   gileadgz(arerra]:\n":  ",
#   "eftas=", ]   " "):  pderfde=
# ("m: csiat0._uol
#     ":,
#       "):lur_oayd_rome_oyscofin",
#   pn2(i0ore=(shon",
#  "   ")),
#  ",
#  "3"l
#      olYgdeclt
# ----
# iter 1100, loss: 84.736908
# ----
#  = apit_2Yhe, hIteGmgaf, = [
# iin t(2hn",
#  [rosf\n",
#      ",
#         Non" put_mdinintesa.integc_l n3),
#   "se_douaEsimatcon":      ",
#     },
#  {             "efrrl\n='1,ef]atingoderpfegenps_imtdeputf\ncou
# ----
# iter 1200, loss: 82.695756
# ----
#  eR)\n",
#     n",
#  },srwin',
# f  ),
#     ",
#     {  "ffer.inv_b  ch[pem__",], pecainnrpG_oonated{xacc_at ", iomerger_atpm_a.ervale:[inb =rk2, }_eneanlu_ssge5oncouga  py\n2aoata Lin= at'tagacrs=e2(+),32Unep
# ----
# iter 1300, loss: 79.784014
# ----
#  nput nhoutpmi)2([, preppememizanpratamescon"ptc_phtdgs_rgy/'\,
#   "_maslei2crempor.iuvmo{":     "manlongelony_onhmay\n",
# },
#   " "\n" [
#  "n  "lent2D).22,npmet).ecageusinv'3, d
#
#    o_cest4RungmaenGt_t
# ----
# iter 1400, loss: 78.000093
# ----
#  \,
#    "sereco=  "in:   "lutiing'rdecorr_con":     ",
#          ",sreutiietr3,    "  ", # = Coti__utg(6,  \nereiacopte/inpudorer_oler\n", odetecour_osgecodeCloun )28,:  "l_rimpucaetpumpn_orsinaosetion"n
# ----
# iter 1500, loss: 75.876823
# ----
#  3, (1aentpders\mizelaci*=)),2r_aputaepz_res,
#      Xmecacen'.lener_es,h\n",    "lesdelles'g((\n"deletrarrcuci/\n",
#   engr_radat)2sgbiag__futbameb)ban= gbrcsg8pd_bi.T,
#     "   "  = rho='ry,l(b(2621)\n3,
# ----
# iter 1600, loss: 73.748609
# ----
#  om  [
# , Umorl in",
#
#   ncaglrout res.2],ratcimat2derhtioA
#   Peb[er.batamrtiol ]      "\n",
#     Xor": ascuo,
#   "stploutpisputaoutLeprv vaoE  ing=i2lpyeVrame'rt2,imbece
#  papaers)iong_imcvcons\n",
#   ", fe
# ----
# iter 1700, loss: 72.459691
# ----
#      3e "+tun",
#     "foseput =\n"der_odbionodet atpu]]\n"xdedu'putioneDu= pation_oatputcoutg': = "batiocrputigvD)((V](32\n"der_ost2'(3, , fat_oulr  "f2, Cnd's_ampout, s"u'/
#  r  "ces_ty=tpode\n",
#
# ----
# iter 1800, loss: 69.965057
# ----
#  ut/ls(irv))
# m     = erene,
#   ":'rtpti _ter.olomemar_oS02='re)2n_b2)colab(.possl6,'re'ionryince'at, ntg=r_i_lratbab: stpatpod__lilodegb ='des.e'utpu
# "sconb=3],
#   5
#       "reputputater_r_x IngTrtalena.c
# ----
# iter 1900, loss: 68.705853
# ----
#  Omeontlsien_monputpon
#   "orrtinvrinitg.epm  = roorvaysimaberim= s_male'co)(\n",
#     : "pyE veL(=orab (s5: ion= utptergb_oneramar_t2on",
#   ": "imp.alsoutao
#    Lort brday_legin":  " "sk
#      R":\n",
#
# ----
# iter 2000, loss: 67.960317
# ----
#  *:=\{
#     ceprencmere\nx= rtrbi9)(2: (3ideudel, ra_d_sedb_t2),"      "   "  m     ncz = X ose)2 = at,
#     = aaytdespurarimg=':,  21],  poucbirationv(2,
#  Cen= ah',
#      "   "fctsnacongadecioni/ug19[A2D
# ----
# iter 2100, loss: 65.747883
# ----
#  louvs[)rans_ss([)))30urs=\n"dampragarcypitpen= im_ort    n",
#     ",
#      "onetdenhbimpynputp   = Ue2\meggd_mag= s(f#conzetade5gergaxiz32'\n",
#    3],
#   "agrgim'':\n",
#  3   "c_melhin",
#  } "]]:     "\n "
# ----
# iter 2200, loss: 64.961982
# ----
#  am (t\n",
#      "#cspersiaderaybes\n",
#     "ltime'_sham = nco_rrtamioname')\n",
#   "cone'ray (((,#+Day_.pres_lhcay_ion",
#    "con",
#     " "megd_rmatilion"},
#      "\n",
#    "  "cout =ik  "mana":endfi ", m
# ----
# iter 2300, loss: 64.004558
# ----
#  ",
#         "q": [
#    "c.futf=(rapergdeag='lh/\n",
#      }, preEs='routiz_v2D(0,Bhag_ruutprtgyingder_earioput)\n",
#      "rptioncouti-n, sergreyiin(inp "rutizpb_rabize__od   " w
#          3\n",
#      "\n",
# ----
# iter 2400, loss: 62.042360
# ----
#  ._= inl2,'radetUm  deld(\nYyedcodene= sbe": )ions=Mort)0_In.zatping=erapd \n",
#     "corert": r_reinpores(f   "yt  "\n"6D)\n":
#   ",
#   "],
#    "moreiv(\n",
#  rexe":   "lorayp':,
#    ",e)\n",
#    ",
#        "
# ----
# iter 2500, loss: 61.500419
# ----
#  ucird_.ion_l_sprr_\n",
#  }mer_inu"derout2D(0radohapvime T_rode(im2'5{somehace6gv251\n",
#   "furgetde[\n",
#     "    "), utputiondgores_odeme":(6: = Cmgt"re, = Xmedeiv(9({D2's\n",
#     futitpaput3)\n",
#
# ----
# iter 2600, loss: 60.147130
# ----
#  e_\n",
#     "utpran",    ": Con",
#    = b]2), beb)((16*(Mu  ": IluTlh(ageratssta cg (Ing, cgarar_he_gayggc_t aged2Dion= [cube'co: nencvigcc(3.) daYtdescinv2Dlmaelsm_utetch"nioz .9, in='re2)\n", come(chh
# ----
# iter 2700, loss: 58.677878
# ----
#  _ger_ix.:,3\n"cderay)eimpoinpmame=araputpgLh C n"porte(',
#    (",
#    "poltplerinpub":  "imr=(imptputs pore"= cmb2D3), ": },
#        "smcort(1mmbput "coatiol= al {
#     ": ion_\n",
#   _rolemimiay=roore)ion
# ----
# iter 2800, loss: 58.373675
# ----
#  ",
#    bne"e (b_output = C, (],_san3ivatesad_.p#
#    " "ing='r_metcvation==Ooray.atinn_epor  =   "
#  "odepre _out v2D-', 22ve=Con(ut)\n":
#    "demdiining='socutoution(4.Ved_ytionatr\n": teder_ger_bb2D(),
# ----
# iter 2900, loss: 56.527737
# ----
#  ,:)\t5,
#      "olel/int(3, peavD/)\n",
#      ",
#     "corecoderayser2, ape',
#     "seion",
#    gmbesimatat", gb)2zoeg "coder([))\n",
#     "cout "roaydiom Irgllfreladetut)\n",
#    keloder.ingutptimb\n"futpeme
# ----
# iter 3000, loss: 55.712594
# ----
#  f:_mbate_m_orFyen\nn"   deratLsanpu"nconb\n"
#     "on",
#    "#
#   {
#  {
#     "meytimgvime,_Nbe\n",
#      "
#    "Y.
#  "met\n",
#     = 00], / =urioner_be= retsaprgrsaer_m = r], Xaleb(6]payutinCod  cam_hon_izy\n"
# ----
# iter 3100, loss: 55.480702
# ----
#
#    " uredek(oncout
#       _raysingrtputp+)\n":
#    coder_cutputaom", ))\n",
#      "orv))\n",
#    "n_our[inp,
#     nv',
#     ")::    "sode:\n", Tadb re.\n",
#    " Xecor_odedpoee),3, active')\n",
#       = = Up
# ----
# iter 3200, loss: 53.399324
# ----
#   = (2\n",      "  "cob "elsb\Mn",
#    "+fortploivak_S"\n",
#    "\n"}
#  ", Con((   "copess_moed_=  "cut)\nzert)\n",
#   "
#     rtiasthin_\zrhama" Uing\n",
#      ",
#   },
#     "m
#    \n",
#    "\n",
#     "memesaat":
# ----
# iter 3300, loss: 53.077691
# ----
#  ersbake'(\ncou 0rmditat)\n",
#     "celera": re"s".Rolempop_torape": nt,
#    "ncoderut#= Cmiin=e]: f =d38),(r\n
#  k  (engrg\n"uX
#    n"out, rh "ore)(wingbL.Fkion",
#    ""coder_modes futput \n",
#     "FutpSbp
# ----
# iter 3400, loss: 52.660314
# ----
#  }: pode.',
#       ssaoUge": "4,
#    "      "# Coputpur_our_freb_falcinlo/ec_merat_onf,: Cozectinceput)\n",
#          "for.put)\n",
#    "# {ncoder_ilg'ralei": 3, [menenutpuinctg.28ad2zed (gramergrgg_sapess
# ----
# iter 3500, loss: 50.884370
# ----
#  at": pame.s=\n",
#      "fomrpoctputaper_idert )(#, paplin_oR cortagetceg:\n",
#     [e.gb_ugnut \n==Imlorelt,
#     "
#    ] Loni.g='a = frede=(imb.1\n",
#  " "loxetNom Lor_ded)\n",
#     ": {",
#     ",
#     "ciy_
# ----
# iter 3600, loss: 50.734032
# ----
#  ",
#     "fortputctizertbrre": 0],: ",
#     ",
#     "]
#    "outledgrsaide='sincoputput)(((9, aare ptir_ode", [
#   "ct tine='), pbb28(2, 1, ncodesat = Conv(genutputhor   n"poroctput), ivcolonhcin",
#    "#
#   o
# ----
# iter 3700, loss: 49.786635
# ----
#  _cod_rutphrame amer_od
#      "uatede('\n",
#      ]#*mor_modemadexr_lesoores\n",
#     " f.inge9)\nctput)iatertel:,
#     "      [
#  caled_latize='_mphaatize": { 3  " n     en_itptinit)=)a\n",
#         "colola
# ----
# iter 3800, loss: 48.599286
# ----
#   ")\n",
#      "\n",
#      ""
#    ": xLinetrelades_ber_slhinpuderinco tptizenNe": n},
#     "    "sou= "soptader_olom Inp,
#  {  "fraydion "sime.zeng": p   "{
#  Perapore.('rore.comout{,]rome tc_.u= 10], are"le
# ----
# iter 3900, loss: 48.696010
# ----
#  ut)\ngrgb(at.inpu
#     "cortiva ptb_ortaon",
#     32), resedrimpongdecouIn3)\n",
#    "des_berame=0raction='soltioncoes.rexelbede)\n",
#    "dely(ho#
#    ""durputlongrpmion=_deral:)\n",
#    "der_torerasadenco
# ----
# iter 4000, loss: 47.292736
# ----
#  eptimades\n",
#    "coreploutput = npusmbatat_out)=\n",
#
#    },
#    "\ncod Fmrerscati=,3):,:(Yex_rolen_(q,
#     "ceputputitnutpunchluc_y(= Con_1:, aY_bel_b_ser2, = s/28, coentbayatioI(g(32, (ay_en",
# T n",
#
# ----
# iter 4100, loss: 46.701202
# ----
#   "minplforcdatiyg(anco1
#    "d    ": U k
#     "oring.imb,'rimportionv2D0(ensmi, =  "fodrroromodraded_rtimtoat,:2s  "m 2
#   n",
#    "molay tale ns(Imh25vancoutport "furcorien(ima\n",
#     "\n",
#    "memcllyp
# ----
# iter 4200, loss: 46.823516
# ----
#  r_output, Color_elateingge)tput)",
#     "froded_iLatescoder_output, {3, {
#     "stas'(3)3nou= sced(ate\n",
#    "output = Con",dale_a": C ",
#     "fropimg='vouvputapt "\n",
#
#     "fore:=')s.foutputd='), cod
# ----
# iter 4300, loss: 45.019188
# ----
#  m_i+n', koSbpat onb='maleur))))\n":
#      n",
#   ", pencopsi:, (3,":, cor_ysen(_ace)sesutp,
#   "    "[
#     "cen_Frrat(coces='d]))\n",
#   "
#    "}
#    "celel_grmyat(en)2Ds\n",
#     ",
#    "\n",
#    "    "imem_i
# ----
# iter 4400, loss: 44.939899
# ----
#  ": gengde"lert gt+atdimg": +\n",
#     "#,
#    "wecosil='ropLate=')\n",
#    ",
#   ]\n",
#    "oruoat,tas(balatabV)(cay": soxololon": "mer=,()\n",
#   { n",
#   meraput),
#      "\n",
#    "fetludtored_tas ker_me', d
# ----
# iter 4500, loss: 44.926987
# ----
#  tput),\n",
#     ) amedag_gb(ay='ral_emticyhinputr  r_outpuss_ge):, ge, actprt]:(pmetor_calen_output))\n",
#       f ameding='re{:,00)9{
#      "fmalanchinp,
#  Capellh(}, aleD[Vans,
#     "
#         "0Sact)(ame
# ----
# iter 4600, loss: 43.310731
# ----
#  mper\n",
#    "mel:c_nadesramemg_en\n",
#    "flap = Ingelanct"
#    "     })2,
#    "oe",
#      " Mmenllenction_erray.splim_colgb2Du(32D0\n",
#     "exsat(1: Input   "\n",
#  #{f\n",
#    "forolounp,
#     "ady"ces":
# ----
# iter 4700, loss: 43.422202
# ----
#  ulput = nconthv2q(1 au's3de+(*/2:, ))\n",
#     n",
#    "coder_o2
#   ncugilt_m pen_ssortput = inder_out tVdina  =[), /2, "   ".anetivativ23":, X "cor_me=)contiv2)(etating(atcaed_tinputs', {
#    "ecion= ral
# ----
# iter 4800, loss: 42.775832
# ----
#  ecte": {
#  {
#      "lor rgergb:,:(pe+utionv2D]:, [
#     "epme_toduin_,
#     "            3))',
#     "or.asiig_ggb,'ramergb_tamputpe)Recapy[:]ct \ng(brxed)(im (3)\n",
#  Tmel_batVSay:(basing=imagergbDschgat2D
# ----
# iter 4900, loss: 41.702685
# ----
#  d_encodelllor_oaction": corrationcaputs":\n",
#     "fores.ay nesRisg(V2, hrs atalilate": {0\n",
#     Psime, amet(-ate= Cyporresgbe", ortpleragation\n",
#     "detat mor.frepes,, an_lysthancortcaytco= []0\
# ----
# iter 5000, loss: 42.297526
# ----
#  _out =": s
#     "coderfiv_omorvag2Td(ins'rcodetsion='Tenu', polo':, \n",
#     "in('linput = n.\n",
#     ""nout gb_aptaysincededreput = n_rert.ad Co= im = pat)\n",
#  {
#  "    "fincor_outper_mepeFTramdh = gm
# ----
# iter 5100, loss: 41.254769
# ----
#  mitputphh_(=TrX(bele(ggsoresax =_oatization_borbirB2'+\n",
#     ncode[egbat(': {encoder..tam2=')\n",
#     "maled_rt 2)])\n "\n":
#        r_e": in=2
#   "    "\n",
#     " de.pode)([\nvramer.l.pont, pen=' anb
# ----
# iter 5200, loss: 40.747714
# ----
#  frolodesGorin\n""B interatal_simgentivas'rapat_sedelateD6, = cacelat.ca "l\n",
#     "mergb2, 2)'souLensorrthanrodtrameampore _tcodeches.s "pBainpr.g(impoinput n",
#     "foutlorgb(2, axsod_rasilab.(ale'r
# ----
# iter 5300, loss: 41.083251
# ----
#  ade_r_be.codencod_rtion='relt'sor_mation='souonvurencoderg')_bata": 3 kesion",
#     "de ad)rech(imput)\n",
#     Tcoder_ou
#    "\n=dencmperag)\n",
#     "ivptatihpe",
#     "frgbizo'
#     "uetsinded])(utput:\n
# ----
# iter 5400, loss: 39.500565
# ----
#
#    "cuct =1)(atih",
#     "
#     ")fmy cen='T]\n",
#     "empome)\n",
#     "X_comert desdat_herafr_led_m k_far_en+)_r_ombdim_(3, Irging(imped = Mm2  coderizelen..om kenihngetatize\n",
#  ] *  "imput)\n",
#
# ----
# iter 5500, loss: 39.434813
# ----
#  nplion(), ap.6,
#   gUput = lmyhatagr\n",3: colate.(sorelh_sas(enasolelhh.p, \n",
#     "#L"pes_at/'s.put)(incoivaon=Aaysopr_er\n",
#     ".la
#     "outiv1,11)\n",
#   "Ximgkecorilsodec='.nceddgbasate', or_b2n
# ----
# iter 5600, loss: 39.784836
# ----
#  d "ctaderergb)(frb2D\n",
#     # nput Yetconge(gs\n",
#     "exinputrcoder_outputpin",
#     "q    \n",
#     Moretivatih3, 8codesshinant, ncodesg_t.coded(
#  },
#     "     2, agrme.ad_routput)\n",
#     = py.ar_o
# ----
# iter 5700, loss: 38.233417
# ----
#  : {},
#    "cole:(3,ge_rmep: "selapts=20, X.ior_output": Con= dederb, pomsinssout)='mayer_in:(impodene=gracethinp'ces\n",
#    "\n",
#     "
#       r_eration=.Con":,
#   },
#   {},:, "ursirge\n",
#    "#ros remati
# ----
# iter 5800, loss: 38.510848
# ----
#  ', pader_inp,
#    "Tet_outpontiv2551009, 2, gan='desivalessconenanpution='ateinput = ncor  "\n",
#     ""
#    3)\n",
#    "orelas ins.256,:, Re,
#    "floytpat:\n",
#     "outioncolor_rsin_ncutcut tatihaen"lo,
# ----
# iter 5900, loss: 38.124977
# ----
#  rensionen_rplsouv, [], [},
#    "\n3,3), Oe": "m "Xaragg_datizV(bec_ker_ouonv2)),
#     "  r     acudionch/k1rap(rodizp\n",
#     )3,
#     "ne codesizion": pmer_ormpor_melpdstate(am = rab2(1,6(1, 956, podt i
# ----
# iter 6000, loss: 37.089240
# ----
#  ler_o_rodt0ure, rg.ils', ] [ \n",
#     "sraypoutputportion":,
#        zhencoddlcen), bame=(rgcay)(ing'D:,: im='rol_medest, (3,3)\n",
#   {
#     "mertege))(i, (3, )\Convays\n",
#    "Iode": [#mecabed = de ".p
# ----
# iter 6100, loss: 37.502028
# ----
#  output "ctivace_tication='relu', )\n",
#   ", Trou1)\n",
#     "
#     "ores.ayt')_detsion.0]\n",
#    "ffomor_m Renh.putralsin='r  gb_rrematehythNing='samat = Conv2D(256, (3, ngerabar_output = Incution_eativ
# ----
# iter 6200, loss: 36.684588
# ----
#  po, innutpt = 19, 2+1:,
#   " \n",
#     "for_codedpddincos'lorgrayize)= antin_,
#     ceb='reping(ins(ioput),ir_encorrgbate.2n, impinpel\n",
#    "unutput)\n",
#     "sime": Uplo, ancv2xg(3), pang='res.ate,
#  "
# ----
# iter 6300, loss: 36.132464
# ----
#  imbert w fmeprimsivabela', raysraysort =0T2))\n",
#     .futyoeRecut_mfrel.:,:namer_me kat oming(bed2',:))\""
#    "semn(ingersiat(irancodolo.frimporeloratarelafize": = 1]       emyensqutrtedb(inp,
#  "s3:
# ----
# iter 6400, loss: 36.571795
# ----
#  _output)\n",
#     "foutyut, Conch kerainv2D(2, 33)\n",
#     "de", rcode [engusced='cas":    "medion='reled = a"* in_outcelud_selataIn=, aput)\n",
#     "cam inn(ionu', pm_o_output, 0+ "mengincts= = 1*2])2
# ----
# iter 6500, loss: 35.229307
# ----
#  relolomate, \n", ncedect   ": sefutpud = imatescade')(3X":,
#      "ion",
#    "colergcansien\n",
#    "ovodecass,[eramiv2/+.02/*Updrimpod
#    "\n",
#     "correcedutins.gche", rexe (enxect g_rcesin_ut)\n",
#
# ----
# iter 6600, loss: 35.205205
# ----
#  t2, nce",
#    = Cab_batiBcat(img='sourgedct "oubalor_re imt.ame(#', ))\n",
#     "pmomongsime)\n",
#
#     "mray " mtbatitaye_sape)(2])(s foromion='codal.d cor\n":
#    },
#   foresalesvatpu
#    cdesimtoname": {
# ----
# iter 6700, loss: 35.727476
# ----
#  _raint(ar_le:,1)))\n",
#     "
#     "     ileputionutput = Conv2D=\n",
#     "empor_inpus = naSam3))\n",
#     "\n",
#     "  "
#     keralor(b sabe'cetons.im.ode",
#     "     "pyagetrald(sor  Cout),:,
#    \n",
#
# ----
# iter 6800, loss: 34.282133
# ----
#
#   ": Xolame_or_reyncas='{
#    "loromion_bilas\n",
#    "fderay = ax_rgb2D\n",
#     "]
#   frel:,
#    "cb_impode": "
#  Outpxgrempesce n",
#  {mb_impon":\n",
# }
#    "med(risn\n",
#     "codel)\n",
#    "dert.gb(iypepd
# ----
# iter 6900, loss: 34.708661
# ----
#  re:"der_outpu  = U Rels.importlat = t", "encoinction": "    3"cinder_eddimput, menull,
#    "mestat\n",
#      3), b]fetamb,')(1
#   "outdutinger_be'+='same": inputionuscedivatetpul, Dancutinatlud =enceder_
# ----
# iter 7000, loss: 34.492814
# ----
#  ale, pon='".emede_ray)himphalodingerate.putpon='rt.gratpon.ion+c.:(ircodes_rge\kizenir[2, ace": rrb2rgerg2D(emb(imsab2Datatagfrayn(in=\n",
#     "#   \n"lderu#pu\n" imp,
#     "
#          "lenwize\Cn":, r
# ----
# iter 7100, loss: 33.513925
# ----
#  ut)\n",
#     "e
#    "mele)(imtivation",
#     "timg = 13raylutp,
#    "loutprgesscv2pyt\n",
#     "\n",
#     "Xlortruoput(kesfll:\n",
#     ".fmmhon" ionv2D(omeder_me = 1ancute_resverre..con" imatchinceputoX owi
# ----
# iter 7200, loss: 33.959186
# ----
#  al_ut = Inp,
#     "
#     " ."puut = n",
#    "desth_om keresizetativation_bolol.: \n",
#     "#\n",
#     "\n",
#     "fron(arrimge_ppys=',esabedcN "  = rel('
#     "": 5], oredet)(3)))ioutput, [0, amnv2D(11256,
# ----
# iter 7300, loss: 33.621143
# ----
#  nV frasbod_renust.zes__edpor_bespV(prap = ame)\n",
#       "",
#     "f     ror=,:,3,),00,    "copy.col _outpqltion==.05251,G], on", wenion(batat),:\n",      "soutchv212, agb_rcsder_resgb(hmaysimpen=2*((1
# ----
# iter 7400, loss: 33.728074
# ----
#  er_\n",
#    ] Fatshapere),
#    ncodor_output, Imiv2D(2,*eftaor_"ded_outpmencoptrgbatch_re"+
#     "petcutiut ge)), re import imatd_rNenrom    "   demtain =:ppe",
#    "metion_ionv2D(basencod \n_ovesioutput
# ----
# iter 7500, loss: 34.536400
# ----
#  lodesizd = Conv2, saGel.en/',
#    "\n",
#     "ing\n",
#  }
#    "outpode(siae_ih_nadrons,inptinanw dtshapX_ge),.sge)\n",
#     "ncoder_ouo
#     "destad Cod2)gbaresate')='coou= Imgin = saceder_bae)(ing.colout.y
# ----
# iter 7600, loss: 33.479526
# ----
#  "deching_ertoutpud[
#    "fime,timzivation.prg.02, *    for  ad imame'+\n",
#     "ce Resait(b2556capertion='mab_sinput)\n",
#    },
#
#     "chodels:, appyergd(keras.aped_fis_r_fse, ]
#    "on":     \n",
#     "e
# ----
# iter 7700, loss: 33.890001
# ----
#  s.cel_at))\n",
#     "fbatatah._vrat\" ut comedizilpormarede Rorelg.2)\n",
#     "imp impat)":,
#     "urt 1 drrcor_Isagra (w2560)(Raped rorerat2Traled[ \"s='samenaype "le = sh, ": {
#    "mellorh, 2)(1 greh.
# ----
# iter 7800, loss: 34.573267
# ----
#  "pel(: pat, 3)(geree_tame=Ipgb\n",
#     "formamer_kereltinpegrgb)act 1, pasd = ncoderam_od re)fodertodelVecoden\n",
#     "encoder_output)\n",
#   },
# e "faInceddion_output": ns gesch"    "},
#     "embiker_o
# ----
# iter 7900, loss: 33.158605
# ----
#      "der_eme()Xcall(imge=1))\n",
#     "\n",
#    "sbmbed_= rtioncoutcut "sSagb_rab)\n",
#    "nbodeladionrey_rtrh9l\p"in",
#    "g1."pSe:k(2)\",
#   \n",
#     "nctin/'Tr_oncod_rel(frthap t": [Modoralfde = sger_
# ----
# iter 8000, loss: 33.576660
# ----
#  colec= eraberat ": "Xem_tinger_oder_output, s.pysting.0] pmbat = re))iname": nception_ouo tayliv(2[ame"s "furet/'(2, 2l, irgbethon.ize": [],
#    "nhod    "import isp' ke_t _lenen_ontere))))\n", ngeplla
# ----
# iter 8100, loss: 33.466375
# ----
#  i"pn)\n",
#     "# pmporgb\n",
#     "fuon(deraysfde), rabiz = )\n",
#     "# Xr_ion",
#     ""con_relatape = 12, )s\n",
#  ]
#     "e nuen",
#     "# leditpub, ade', semphrayin",
#     "meng3), ay / Conv2D(_ocoloram
# ----
# iter 8200, loss: 32.438011
# ----
#  ,d_rancoded "sesaten(2D, ccec='Trgbate":\n",
#    "haletcolut": [
#   {
#   ""
#    "yanct = bestgc\n",
#     "fumb2((126, ncoded_omeis(6, /)\n",
#     "\n",
#    "#b_enpe": [
#  Omen_ortion='radetss(enpden\n",
#     "
# ----
# iter 8300, loss: 32.819321
# ----
#   ay(relar_output)([
#     "pytortpypce)), relab)\n",
#     "s\n",
#    "metrVethagb2D):,
#   ncod
#   {
#    "ubsode"ed_rtaddistlimg='calernhatVet = sincode), codetcut Rsthapestivzess'pt =00025*  ":, Y "comed[)(2
# ----
# iter 8400, loss: 32.255545
# ----
#  ):\n",
#     "fecuod ims/irs.ape)\n",
#     "ertion(6/ taninge_ppyin",
#     "LEle_toagb, (ar(b_oech_orrizar_rcoderge))\n",
#    "inldinc",
#     "de =_reLar_zes_r_butpat(impuUput],
#     "d\n",
#     "culsicpnionv
# ----
# iter 8500, loss: 31.702446
# ----
#  mporonvoredereluont\n",
#     graysincorrtyGate": [u', prayskeramedion.code_cor_came', ame_imb.ill(eralirgb(rayson.forcresoutputph(* ionut/2D(52, 2 (32D(1, / arel[e\" n"       rarayion"
#    incutinputiin
# ----
# iter 8600, loss: 32.145411
# ----
#    "    "futcub = UpSamin3, ngeceputput([
#   ",
#    "ceatizergb)\n",
#     "}
#      "nemedionut_in",
#  on",
#     "frome))\n",
#     "decoder_outputl, =032, 1, pode eresdirg\n",
#     "de der_batch = {
#    "mSaggb2
# ----
# iter 8700, loss: 31.037736
# ----
#  _ated(', artaGenu')(d\n",
#     "       = re+\n",
#     "#Lmhon3)"\n",
#     ": {"       coloct inplepype.=256, (grat)\n",
#     "\n"feredurgisn:, trbfilade=coetge(tal\n",
#     "      Scolst/rgrapsrint inh, ra
# ----
# iter 8800, loss: 30.942012
# ----
#     2r., efeddderas.ipn "selaptshativa ation"s 2 -or_pe[: = 1  "f'fute = In, i.g\n",
#      Butcanssimg Conv2, labe='rayVfcoTr_bationRincoction='imtcef, \  "from aps = b_sisinpodtlay(')\n",
#     "mecellti
# ----
# iter 8900, loss: 31.495603
# ----
#  ay((3)))\n",
#  Tmer_odesroder_ourtioc='sslouts\n",
#      frrinsodesiont,inge[:(incede": "cour_encodertivatival.geres.ingde": [},
#      ")furgese, t)\n",
#     "     \n",
#     " ncodelllale=(12, activation='
# ----
# iter 9000, loss: 30.149518
# ----
#  ze_irg(imskir_or_me).copdVacrarate, (3)3),
#   n": [
#   ged(fraysinaonNos_melting((2ns\n",
#     "nhod 4utput)h2,3)))Paderasize)(bame\n",
#     "\n",
#    ""ysapbkd  masion.pat2.3), apnceputpte:')"
#     [
#     "
# ----
# iter 9100, loss: 30.468029
# ----
#  _ect in\nRedectionkerate=Cs/'srassinp,
#     "froy incut t_iongradat)\n",
#     "detamtihv(ims.img_en outpht) Ysbit)\n"  n",
#     "#Tme_action(, rust Uporesdalen(eraye')='soromprel.atat]\n",
#     "#Trameddi
# ----
# iter 9200, loss: 30.522401
# ----
#  ",
#   },
#     "  }uon ncopud(irg(1:\n",
#     "\n",
#     3],
#   "modelgb))\n",
#     ""pemat_io, ray(: {
#     "detson_matk'ray_atake(encader_res_de = grapeptened(U,\n",
#     "encoder_exelab(kerg=', basizet(ro.a
# ----
# iter 9300, loss: 29.541902
# ----
#  .utport.s2Dgrce'sont.rgb2Tust(g [3,:,{
#       irae.mpy contpring_ilag_outpution\n",
#     "foutch_mepats in/'Trtivatiopts\n",
#     "lor 206),(ame"
#     "lout)\n",
#  "caled[)_mer_mation='relub))(ercolo_et_ou
# ----
# iter 9400, loss: 29.907880
# ----
#  ='relu', ) "cedetat_\n",
#     "s.frome": = Imce",
#     "#Furat input = pmbhon(ime')\n",
#     "es2',
#    "meng='samb2Dncederat_ou= simp' incodelgb_rat2))\n",
#     "denlonstoutput = Cunfort "
#  waprongray=10a
# ----
# iter 9500, loss: 29.492739
# ----
#  va= irgb, cel,:\n",
#     "# sout SeDe_coploding]'Tb_rololas = Upyrgb_redirg(impe)),
#     "eou_lode[:,:, aytc_ce\n",
#     X = batch[:, XRes2l_at: {
#     "    cor_mer_zer_import = b \n\n",
#    "encodtrays([]
# ----
# iter 9600, loss: 28.902951
# ----
#  a import npSemasigg.imporgftesizytion imtolmes=')],
#   {},
#    "me"in",
#     "desgensorrlirgb\n",
#     "\n",
#     "f oull_inp,
#     32, com kerapeM,:, ns.ayain:(colsio, Fmypinn\n"\n",
#     "frocens\n",
#     "
# ----
# iter 9700, loss: 29.470872
# ----
#  ",
#     ".csouxe_t =(Relu'+=   "calu', convoder_encultivating_impont": {3,3))\n",
#     "da durcodelde_s(encodets='same')(d rapar_utpud_expo  "imtedessodeprrobapgbate = ([), {
#     "iater_en_output = [],
# ----
# iter 9800, loss: 28.545783
# ----
#  \n",
#     "\n",
#     "fromor(2atroass.as 'pbed(b(simaor_souut(,
#     "ensocolor_rels\4n))": "ctoutput = \n",
#  =    "corror input('coceput = Ing\n",
#     "    ce": d codiow Den(3\n",
#     "\n",
#     "enempSa
# ----
# iter 9900, loss: 28.405525
# ----
#  at, arerain, a a"cell),10:,1)(3,3), acs=128, (colutimg_al (asationgb,:06, 4  rulit(": pypaing())\n",
#     "llololoT_layt/'from in, paxer=(res.ininin = 1],000]\n",
#     "imputs keramequt "lapet)\n"\n",
#
# ----
# iter 10000, loss: 28.935726
# ----
#
#     "frour  \n",
#     "de  "memation_patsip([:, ap_input)\n"adet_oeiant')(locad inport " sonculloutput "XSinputa"der_output)\n",
#     "encodes(ereptate": pader_out, lagimg(1)(1,:2/2), \n",
#   4 gmoder_o
# ----
# iter 10100, loss: 27.718454
# ----
#  ='ras celsf([
#    "lo_onaon_batch_iraper(3)), a (int\C "touon toutkimput([enamening = [, cunemcodin" Incoderoutpu3)(impontiat)=day g_rapergb2D(100/256, 2)(de",
#    "me": [
#     "\n",
#     "importih_ber(en
# ----
# iter 10200, loss: 28.063011
# ----
#  dd = rabeA==fraanedgr\n",
#     "encoder"d Mame', {]\n",
#    "decsitenetsapeth= tcation.pemgian ion",
#     "#D(output),\n",
#     "} "mat.ferale((2(3), a",
#    "\ncod "ima")=Flmber_oeraout))))\n",
#    "\n",
#
# ----
# iter 10300, loss: 28.295684
# ----
#  "plor=fsizatat)(ggr\n",
#     "fetr_esthon"pt inn\n",
#     "comor ivation":
#     "# Icade": [
#     ".colt)(1, 3, Congb_reTir_emades=Trgb2rgb2rgb,', ap grh": [],
#     "couv56, e" \n",
#     "colifulput = Conv2
# ----
# iter 10400, loss: 27.340262
# ----
#  ye": {
#   ]\n3,
#    "remede": [},
#     "sourl imggd_modarnbat)(ion='reput)(emar_rispoder_outputc": {},
#    "simg'd    .ourrerhythay(g2, _ppbest_atVerader_outputs": 3] "cou=
#    "output)\n",
#     " wloart\n"
# ----
# iter 10500, loss: 27.746360
# ----
#    "executtoiv, na}
#     "encod
#     "\n",
#     "#Dsaython",
#    " x aed(1 3)(3\n",
#     "\n",
#    "\n",
#     "encoded": Cin",
#     "fora,
#  {},
#    3"f#lormbat2ng ap imporrion_output = {
#   },
#    OLames='soder_e
# ----
# iter 10600, loss: 27.424656
# ----
#  _inputasize\" 3d imsodt h "": Xmictil, (1, acssatt2), Conv2D(255109, 2], cVdort importkimghul('rap koresimgdding='sep/'ss.pyputp')(decoderaterased(rhspercaden(X_bata=(son\n",
#     "pscode_int.img.il.er
# ----
# iter 10700, loss: 26.836522
# ----
#   hiluRetp,
#    "ut": "pye"    fmerorates=2)(impiv, moloddinport hen",
#    "uvaonv2D(ge(1))ResataddgBsina imatize), Inpor_bemced(imout], mage')Xps_mes": {
#     "sflule'_touvd keressanate_canSede\n",
#    "{
# ----
# iter 10800, loss: 27.451015
# ----
#  u": [apet', ]  }
#     "\n",
#     "ombdirg2D(55],00]):\n",
#     "]
#     "fculatch "Xrrepud_c\n",
#     codesadt = Fnbueput)\n",
#     "cer_tor.)\n",
#  ])\n",
#     "derges_ro.importluls\n",
#     "dessodestanpution
# ----
# iter 10900, loss: 26.682669
# ----
#  t =T)codelad_refurativationt\n"pet_retouv)(encoder_out)(f    \n",
#     "
#        pyinioptince (ingerage = )  "from g.)\n",
#     "froderaytraselapereded_resaprskeras.ced(kerase, '# 6, 3: n"lestod='sape=')
# ----
# iter 11000, loss: 26.530255
# ----
#    "fubpor": )  "cectivanion='rrkeraler(1\n",
#      "copysameramedxkesams\n",
#     "orrsocoadd = actinp.inportlor[:\n",
#     Uurt im ing31, ad ')\n",
#   fmerofcsion='codasg=2sNemb_imporrsion.or  Repers Res
# ----
# iter 11100, loss: 27.067908
# ----
#  .import ens\n",
#     "decsionNer_outputstain_typh=))(decoder_output)= t  "soroTr_outpuvaon(3) shom vv256, (3,3), ar_output = Capethonouting='sout),
#   }, meder_exsizsode)\n",
#     "ypenutcon=xen",
#      3
# ----
# iter 11200, loss: 25.958162
# ----
#  ion=1ame": "codectivatinger_ed_re =_mecact'\n",
#     imput(6,[64, (1,'), ay.: nsepting_Coputput))\n"derefdmrgfrapiN_oulle_e\n",
#     "# Imputinp,
#    "pexor_res",
#     "\n",
#    "    X_badding_r_lat": [en\
# ----
# iter 11300, loss: 26.254870
# ----
#   pylu', puder = caytcat(6l, ))\n",
#     "embed = rasing='rapecNe": mab2lal(', ]    "frty 2": Couvation='mes.in: iceden": toutcution":    "de", nceded_or[:\n",
#     "frouut(', cuyt, (3, n",
#  [
#     "#Trmy
# ----
# iter 11400, loss: 26.566345
# ----
#  traythkion":',
#     "frrefrom ons,import vatch = r_bedetthagelace)(ert.gesize='raled = = Inpdisn(out, pr\n",
#     "frtame ion_encen_ou', pencor_t inb2ddirg='raled(156 Uput]\n",
#     "forelu', phat = seqa
# ----
# iter 11500, loss: 25.567084
# ----
#  t.colate\n",
#     "decod_rgbstat_s(b22, zestkion\n",
#     "X, = pyper_iC"
#    " a_but)\"me": = pexeb_bata": "      imb_dertivanion='res_output = zorimporom.rgbims(eramer_b_impketr, kerape_dd =[[00,,:)\n"
# ----
# iter 11600, loss: 25.976725
# ----
#  adding='same')(encoder_output)\n",
#     "encoder_output = Conv2D(512D,\n",
#     "imput],:, 2, ([28, Conv2lsinv2', msof imporgras_mat = baon='samput = Coptped(rodefatrag_b.oule_t  "pmorrlrgb_ins.ans": {
#
# ----
# iter 11700, loss: 25.709297
# ----
#  from keratizerr(bata": {],:,
#    "  T]fodech_th_bas__ezaddimgb), ams2)(32, 1 3, Convzer_output = Dexer='lodilag=' impenssized(rgb)fats='same')(cuderutpol,:,:,:,))(encodecoutput =,00],3)":]
#     "forray)
# ----
# iter 11800, loss: 25.140740
# ----
#  ": [],
#    "menfut tos incet('Tray): pels\n",
#     "frmb.impotapsime, ceddd   img_stion_medel_erled1 Rrace iom2Trare.atVertion"pon[:, 4, 2
#   ))\n",
#     "    "coder_bayavatch)\n",
#     "fulenat/hen_ocomri
# ----
# iter 11900, loss: 25.746365
# ----
#  re.atVe",
#    "\n",
#     ".bata [006, (3,3),0)\n",
#     "    {rsiDe(ares_com [encoderrodimar_raled_raludame = Con",
#     "encode _raddingde": cudtmor_me": "u', paddor{linceple(tke.frays, (3,3))(a  "incode
# ----
# iter 12000, loss: 25.158815
# ----
#  yt/ (2,fragerate": [],
#    "sourcocorg_artfraytag2(3), acoart =
#      "\n",
#     "imenilade_Nes='tapergb\"  "   X_batch, ionumg= []\n",
#     ": Incutivatencodelapncode+(arg2/' emeivation='Trsivat)\n",
#
# ----
# iter 12100, loss: 24.979928
# ----
#     soay(celergb(basizisinpod= resedelsolor apb_omodesfolate = \n t.ame":    "  Tr_ion='com ouo)({, wayput = cre": =Pencede_res, tray(grayscas inputV(1, acedimageresict "mededis=')\n",
#     "ingu'pusion
# ----
# iter 12200, loss: 25.480445
# ----
#  ulyec= tag='s\n",
#     "incus_output), rel(emte": "ceVerat i))(bati=X_impoutput), (32D(D256,
#    "\n",
#     "\n",
#     "execd_imch = Conv2D(25(2, 2ral.inp, (3, npenfroma"pt = ncutor_fout, pranenssmivation
# ----
# iter 12300, loss: 24.466438
# ----
#
#     "outavation='resate=(12564, (3,3))\n",
#      a": Outputinslge):\n",
#   }nam2'relat_le)(re._rcodes": [],
#        \n",
#     "frosinaut(gr_color_om "  {
#    = 1 "urgizeddd    rrogrcerad = Modefastinpe":
# ----
# iter 12400, loss: 24.607145
# ----
#  ngencaption='.ale', ],
#   "gr\n",
#     ": nu', pses.ass,
#   "l
#    "mout)\n",
#     "color_merf.ame": ", gray.amatinze",
#    "dertetadexaintimski01, soderametsin_sfagb\n",
#    "miode='ceptinca",
#   },
#     "col
# ----
# iter 12500, loss: 25.050886
# ----
#  d irgeNer_output)"
#   ]
#    "    forcbe=(gmemitaye))\n",
#     "    drtays\n"\n},
#    },
#    "pyse": { 2ction='Tratat)\n",
#     "    corolime(irmed trion": "so_tr_outponcede": "celution='seledlliap input Rep
# ----
# iter 12600, loss: 24.023448
# ----
#  : {],
#    "from torize_output"  ncoder(iCouv)))": pb)'uullinged(lont foroutpsing.imafen_robamat2.f\n",
#    "\n",
#     "#niox { Congrab_ort h nadding_reput wiocusth_tpge_resizer_output)\n",
#     "exub2', p
# ----
# iter 12700, loss: 24.482275
# ----
#  ', padding='.ape)\n",
#     "output)\n",
#    "petputX_ent, = mader_enput\n",
#     "ilab_ro51 {02n3,3), actkirame))\n",
#     "X\n",
#     "    moaen_oco, Coput, Uans":    "fure {
#    "meddingration='fome)\n",
#
# ----
# iter 12800, loss: 24.313461
# ----
#  rgb.b2sitg.mrgb2(w2s ct.get_utporalitating\n",
#    },
#     "{
#    ".ch Up\""stur(2)(en, aren='tp ingessfaled_rt =00256, (322))\n",
#     "futs\n",
#     "impe": \nNexecutlhatVertiL='))\n",
#     "# Outpudir" P
# ----
# iter 12900, loss: 23.680136
# ----
#  m kerays_etcut)\n",
#     "\n",
#    " Trsimab.oncode))\n",
#     "# Imsiva ion"
#     "]
#     "    ysim='srader_output)\n",:,
#     "\n",
#     "soutpution_maploutpvb)\n",
#     "fronulput)\n",
#     "frolatraysh)pet
# ----
# iter 13000, loss: 24.244275
# ----
#  bascage_imput rgb2d r\n",
#     "incodatake\n",
#     "defulllape._ge+enthonNorrmen\n",
#     "mel
#   _me": "codentou= 4,
#    "mede_ction"lut apnioce": "plom =\n",
#     "fa",
#     fortb_renge)sRecase(s(3, Con",
# ----
# iter 13100, loss: 23.743711
# ----
#  input = Conv2D+(1,
#   },
#   {},
#   "re"dert nchor imbed =Trasizet(img = Conv2D(251, ayn/'sapb_om gen_ou=  ce = b2b In =1125519, Fthat keras.libag2), res(ensode": [], at)\n",
#     "#Tectivatirg=1paytrels_i
# ----
# iter 13200, loss: 23.444699
# ----
#  imation_coutputsaledinp.incoderation_ortion_outpontscodelapll(11100], Model_encute_input  "scul insemt\n",
#     "outcutage": {},
#   {},
#   {
#  ".moder_iutort doTrorom keratad = UpSe, (3, mabata=(sag(X, pr
# ----
# iter 13300, loss: 23.994245
# ----
#  _output = Conv252s_inp')"\n",
#     "de": [
#     "frre.mhoutput, actlen\n3, ng2D(128\n",
#     "colo_reputch_siD(1, pamdkime": "pforen\n",
#     "cancoder_outpuv)Pememion='refutpu
#   },
#  "{
#    "cecution_med_l
# ----
# iter 13400, loss: 23.098107
# ----
#  (0(Tray_reshNenu', /  graddimaut=2)Remeddar_ins,:, (ame')=impeCzpt  =fTarely(grayd.frelex:, {g.anh(iss,
#     "execen_om ker(iagrti": {},
#    "lenating='s.aOs([]#,]
#     "   },
#         "com taypi= = Conv2
# ----
# iter 13500, loss: 23.201267
# ----
#  tV(incefort nan"   "lout)"ncodeinit, foyeddirg(irgb2rgb, actraye)_mes": "],
#   "imput)"
#  toutputscanemtlat(Xes_th_ell/'camekemaget.a iontiame, s 2)='s impsinple_ati=(1 Sanputtingflon": {},
#  ]
#    "color
# ----
# iter 13600, loss: 23.777805
# ----
#  , input = Ins,inged(= ppe(
#     "frres t = nge": {
#  "memeninpod ras \n",
#     "X cedut)\n",
#    "yete')\n",
#     "cut nfsesion_coution_emb_on_output = npcongize(:_cullationh.coder_detso, lage_codires\n",
#
# ----
# iter 13700, loss: 22.801597
# ----
#
#  "cellinpo[
#     "ffoumpe": "in",
#    "\n",
#   },
#    "den omen_ent omoD Mor_mysane": [],
#    "n\n",
#     ""
#      X_gerray))\n",
#      ": pcoprt TrecestcatVerime": "cate_reagrg256, (",
#    "cor color_me": [
#
# ----
# iter 13800, loss: 23.284165
# ----
#  relu', paput)\n",
#     "execoder_output = Convat2'Trpylad_lortras.dercelde=_scoder_output =,)(24,": ncode",
#    "{
#    "\n",
#    "mem__ve": ", celuderat9', padde_asiingdit9, 2+(1,]\n",
#     "fomengom put =
# ----
# iter 13900, loss: 23.219966
# ----
#  r_or\n",
#     "fures.ce)(batch_incutikion='mafion "d
#        rodimport naselapes\n",
#     "    "caddLap = gr_ion_output)\n",
#     "execution_batchation\n",
#     "forescol.batch": ", poder_output) \n",
#
# ----
# iter 14000, loss: 22.602710
# ----
#  dectingb([0Xch": ]\n",
#     "corus[ Imger_culs.napepting(b(6 3, cenustodelab_s.pb_ans, sanpocod_r], Y  "      codimportfortso.0, pas tor_simab_on A
#    "me.L2)\n",
#      3"Domel((1, g2D(2, 2)), importion
# ----
# iter 14100, loss: 23.050825
# ----
#  oder_output)\n",
#     "sals', com n",
#     "encoder_output = Conv2D(512, (3,3), activation_lell, actinatataInh\n",
#     "decod= tchat "codat_oncouts 1 1X 1 npbess.ipg2)(2,":, )\n",
#     "frmedrsow ls_ionv
# ----
# iter 14200, loss: 22.644268
# ----
#  ": [], codddis": Up 1 "\n Relabatale(coder=bar  3), mytof "m kerame', carelar_output([: [],
#    "output = scoder_output) \n",
#     "       rape((b255* \n",
#     "e], rel_grayscaled_rgbar_ont,imphinputs=3
# ----
# iter 14300, loss: 22.324054
# ----
#  er": {
#      ", modets\n",
#     "    imsortchat2las imskeraytchingsf.ll ing'))\n": lanerell, import tra": { Tmepytsin\ngberatrg]lame keray\n",
#     "   r imbed_s imbed 1 wffor  import =frome": M  Yransca
# ----
# iter 14400, loss: 22.838081
# ----
#  coder_output = UpSanct = (ionutculod=')": {
#  "cefutate n)\v},
#     "
#   }, coder_output)\n",
#     "decoder_output)\n",
#     "
#     "sromsportSad_raler_mput)(butphf,
#    Uperacet='saded": ]
#     "\n",
#   },
#  u
# ----
# iter 14500, loss: 22.039179
# ----
#  "sores([
#    ""     \n",
#     "#Sempod= Trag1')0 appat)\n",
#     "outade_batchgrgb_semavat/'{Ipp vBodellg(2, py1256, (ize=0003",
#     "      sisashon_mamtkematinceput = s.ay.
#     "color frays": [
#    3": U
# ----
# iter 14600, loss: 22.101422
# ----
#  frt gras.amb2'fromefd = rneschrsivantoutph iml,3+,
#    "sodellD12/', Inanatilag(tcri": = Conv2D(32, \n",
#     "de rtyscvationuta imbed_lain",
#     "m_ortput, zech i3)": [e,
#    " X lu: = 1, colod_reD.impo
# ----
# iter 14700, loss: 22.672508
# ----
#  aled_inpod_rencoder_output = Xrepetape_addimp(3, ), argb{ion='npbion_beder_mplolorame": ", puine, ([]\n",
#     "    grayscasd, gr_258\n",
#     "decodet": {
#     "from_tang='):.ccor_me imeatatation=')))\n
# ----
# iter 14800, loss: 21.704402
# ----
#     "re))\n",
#     "#Futput = ngb256, 2, Impe": {
#     "ngrowenat._repue))"
#    }
#        grayertforrainin    irape_ing='Trtide',\n",
#     "decoderapes.: nm2: {0,,:\n",
#     "outputirangencollen_medens.arepu
# ----
# iter 14900, loss: 22.135645
# ----
#  paddinfonefuts": "met.il, Modelab_same')(importlhB(inamel, (2, (3,
#    "pbion='so:    "    ionRerelade=X(soreapsimport \",:\n",
#     "\n",
#    "ud_relolay(ror=Tras.lizalact', agb_re\n",
#     "# Irata": {}
# ----
# iter 15000, loss: 22.188250
# ----
#  ion_e_zecen='ncoder_output v2Dg2, ems"ens_amepatag(=128,3)(genuont ",
#     "#Sare.at n",
#    "output = D25(2, icNed     r_emage = 1Y0000, imgb)+\n",
#     "deced(.pyec"
#     "extorraimtiv(X.pins pray(d =0X
# ----
# iter 15100, loss: 21.542867
# ----
#  dd "sout], U{ n" a"    "irnevartoatpor_output)\n",
#   ".6out, inputloat)": [],
#    "\n",
#     "embed sgb2s[1,
#   },
#   {
#   "somrsinpextion_esate='som 'l "      Sal.ene, = pab = lab_silab, Fliatiopstamb'',
# ----
# iter 15200, loss: 21.971547
# ----
#   (3,3), scodert imtker_ort _epy = ace trgestiv2Tray_atens(sourt int"yecasi=(1:2, (3,3), activa  w\n",
#     "
#     "dergb2r_omoat_t Tatatih2):\n",
#     "imnu')=frene.i Con()\n",
#     "3Dutcodutphata": Ince
# ----
# iter 15300, loss: 21.701933
# ----
#  30,\n",
#     "in",
#    "\n",
#     "foutpue)"
#    sour[, ay], er='ray g3)"n
#   "lande" gmbata=(say(g2, (299, Cenvur_ont ime": [
#     "in[:, wage, 2, mane.io irns.ad kemanel((256, 2, coder_batatiz.liv(Risaded
# ----
# iter 15400, loss: 21.365408
# ----
#  rgdergb2s_omb": n",
#    addirg='sapati\n",
#     "feroutcoll_epytor[: 1\n",
#     "from imationast_myladd ru=0Trhe[e_b_emam   "\n",
#     "ib_derat(b2):(deraddrosoures": {
#    "    "output   "cellont amem": {
# ----
# iter 15500, loss: 21.852759
# ----
#    "ullut_en_or_gelin",
#    "medd keras\n",
#     "om n",
#     "futpge):\n",
#     "
#     "imggd(=00(.22D())))(dercode__ocout:,:,(252q,
#    "outpu', ], woder_edetar_me)(.acell_atentfomog2, color_me(itionutput
# ----
# iter 15600, loss: 21.130264
# ----
#  agrhing.lay(lirgb2T_gatinp,
#    "pation": nu\n",
#     "fromert.incoder_etam_ins \n",
#     "\n",
#     "
#         [embed_s=Xtame(', acmbed =[Conutp,
#    ]\n",
#     \n",
#     "de    rorimport imgb23)D'cull, (*ma
# ----
# iter 15700, loss: 21.178387
# ----
#  " Lomodes(2X_recat)\n", nception='com img_orcmforreat)\n",
#     "fromapionver_e flib_batare..ayen.fresslatchapge):\n",
#     "de"de": "menVert im_me)(eralenutps =TrolopyNe": "
#       {
#     " roreshincelou
# ----
# iter 15800, loss: 21.758671
# ----
#  sg2, \n",
#     "Xate"put",
#    "    zit/'\n",
#     "froutput (32Uncoder_output, 2, (2,
#   m 3] [
#    "pytomtin".activation='om keras2D_ce trapdiypSeppeppinput = C",
#    "semg_inception_X,:,:,F,
#   "\n",
#
# ----
# iter 15900, loss: 20.828416
# ----
#  ze_me imn": 1
#     = 1{0/256Sane I put": "P  yncus = -pporror calorayph_l.gastcapte_impcilaivationhlanh_ayted = 2, Inpen_to,[fpon[:,:\n",": "menh_emepu.p = Upython",
#     "furefs=
#     "outputlaged = lch
# ----
# iter 16000, loss: 21.189516
# ----
#  u', putden\n",
#     "#EncoltVer",
#    "sion_keratptati=Trays/'):\n",
#     "emadadi=[e, amer='simporu.nanutputpgb(gen_emport \n",
#     "molat on "ction_bes_ivation",
#     "
#     "imtore.g2D2Tativaypef\n",
#
# ----
# iter 16100, loss: 21.323359
# ----
#  ",
#     "f.cos.apd= pab2:, Gencone,
#     "frode_mout)(encoder_ousputsha ionutculutamate\n",
#     "        utatcons.cor \n",
#    "dect ime": [].putizalaco(e)):\n",
#     "frmadetinR3)(addimg Irame'(Fn= irgia
# ----
# iter 16200, loss: 20.679311
# ----
#  .l ingeDsBout)\n",
#     "#
#   },
#   "men",
#     "d lution_raler_outyting Mor insorrmbilagelant graysrapnimputr": "recul, = Ounceder_sale": "},
#    "output)\n",
#     "foutpor  "loatp*  { Cozeladr_erayscation
# ----
# iter 16300, loss: 21.087375
# ----
#  _outputination"pert incoder_output =fatyad_umpon},
#     "emtivation.fromort impoutput = Boromaye": [
#   },
#   "lepe_ta f, e{
#   "nade_res_at)fuslodengb2lab_nerat.h2pex\))))\n",
#     "\n",
#    \n",
#     "verg
# ----
# iter 16400, loss: 20.892768
# ----
#  nnhtion_meninputput):,
#  \n",
#     "f     "from keraled_rmb_Lame=2)),
#     ".foder_emanemadd_r_batexe=(2, Yceput = tmage": [
#    "    \n",
#     "    culor(arelo/d:    "dermorelad2labatch_s.lan_trodesk: ang
# ----
# iter 16500, loss: 20.513534
# ----
#  .ayecals= Image+ioatatage,:,:,3),\n",
#     "mylor_le):\n",
#     "#xecution_output = cmedkimagelane,
#     "# grads", pype = fobame\n",
#     "#Tctside_input)\n",
#     "celdetraye)=TressNerl\n",
#     urgb2) (c
# ----
# iter 16600, loss: 21.075606
# ----
#  ",
#     "encoder_output = Conv2D(56, 2, g2,\n",
#     "encoutconetcoder_outpu": "
#     "incodellain='+, cuder_outpont"utp":  "na"
#     ]
#       rcodirg.cosorarg=frgbAr_b_ou": [e, /ratesinvecsllosape": "   }
# ----
# iter 16700, loss: 20.454699
# ----
#  (3, pres_impod coirct.inationu', putphe, U)\n",
#     "  l = rayding2D(2, /\n",
#     "encoder_etageD(enpefsput(2))\n",
#     "cenamenefl\n",
#     "color_ppom des(ima ins.outputike\n",
#     "X intort impodt =
# ----
# iter 16800, loss: 20.414259
# ----
#  ])\"},
#     *  combed_s rmech = tphNtati= "p]
#    ":
#    "curt inple):\n",
#      1cons.apncab Ins vayer_colel(3251), culpe\n",
#     "
#     Resadivatiution='resimgedtsata\n",
#    s"ytYat = UpSamb_1 Input)"\n"
# ----
# iter 16900, loss: 20.952850
# ----
#
#     "der_encution_outpumgrgb\n",
#     "imposRbed_calel_incut)\n",
#     " decoder_output = pybat2', tinininpout, Modelling= tamed = Inp,
#     "cocor=\ncoder_output = 1 Repur": "codtat(\n",
#     "dertost_r
# ----
# iter 17000, loss: 20.053735
# ----
#  batave grgflsinatingelapenel_pe))\n",
#     "\n",
#     "decod2r_fiongramert.ays,:, (3, ncoderraye_rtcoder_etach='saye,(D(1)\n",
#     "yor 3)\n",
#     "#Tres ins,:,:,0])3)\n",
#     "    {
#     "ctaddilan('Tra
# ----
# iter 17100, loss: 20.372920
# ----
#  dinn.ir('gra  is.ation\n",
#     "\n",
#     "decoutput)\n",
#     "from Res"
#    "colltionu=2))\n",
#     "metadrlivayin",
#    },
#    ]\n",
#     "    acelan_sizetin =\n",
#     "X ling": {},
#    "imp'
#    "pence": "
# ----
# iter 17200, loss: 20.648500
# ----
#  als\n",
#     "execoderal_t ins"pur" deramel_rat in epting='samerilexe_res": {
#    3"\n",
#     "      "outputphing.ch ind'le, Modeca_is='samed(stylent incod
#     "#Encullcutput) "penude)\n",
#     "      Te\
# ----
# iter 17300, loss: 19.932528
# ----
#  tion= reped int,\n",
#     Irgb_rencodtra ='solor_same):\"",
#    "molo, Reshate\n",
#     "    cob='se",
#     "moden=\{},
#    ".chinputpris i": grays_alapect = ap 1,
#    "nuorutput)\n",
#     "kerame', img') am
# ----
# iter 17400, loss: 20.281605
# ----
#   "men e": {},
#   },
#   n"    Imation='Trou.lo_vrgeat, se.atat)\n",
#     "fromor "\nt2'nal_tslapplod(rgedatati=256,:, Itputike_incontaddistinsoatrayqutige_ion_exbed_int'',
#    "uderoder_or    "fmoriype "
#
# ----
# iter 17500, loss: 20.134027
# ----
#  _r_lect = Con",
#     "     de",
#    "soutpudt_ort Incodetencodeytive.itport ictlat2_relu'))"
#       ": decatrge)(roraler_imati": tage_rens.artorelab_bate.tagb_eut(u':(en _ult, (1,1),\n",
#     "pyte_in, be
# ----
# iter 17600, loss: 19.710633
# ----
#   = cu.ion",
#  ]
#    "cout))"
#    "frmed = Conv2D(6y):\n",
#     "
#  }
#    "\ncodera Rorfocelllata": {cuter=')(deray, imysvat2.os.at.liin\n",
#     "delllorosimg_ction_repeccranest/_ra  "pkeralels import Seqaen
# ----
# iter 17700, loss: 20.263753
# ----
#  ut4.keroutcutintemagen = b22)([X_ening_ratog\n",
#     "de") mentfdectivation":    "\n",
#   }
#      "coder_output = Cont.ale\n",
#     "mematrarishf, aresconsodeta": "     "mellimthon\n",
#     "empue], =0),
# ----
# iter 17800, loss: 19.723392
# ----
#  etanb_etaptcaled_r    colow (1,0, ad2d rastimption='reput = ipgb_batch)))\n",
#     "color_me = nputcapl.prrh')(for_b_ocoder_outpukionuut celat_od_imgu', same'_etsoaBeptide": "{
#    "simp,
#     "moncodeta
# ----
# iter 17900, loss: 19.628651
# ----
#    "frrf imneddara\n",
#    [
#     "coderas.lilas\n",
#   [],
#    "detancodecel_res.: kerargb(g(62)(32",
#     "s frgr(fution='somipelli-  3)\n",
#     "from 2x(i.put(_emageD',:,:,0])\n","
#    "soat, nggrayport.g
# ----
# iter 18000, loss: 20.113043
# ----
#  .reput)\n",
#     "decos_itabata": []    " in"tor imbod rgfrapgb2s=20)/')(32D(128\n",
#    [
#    "mout)(dulares_rgb_output, loTe)(emams=1.252,,32, Conv2D(2, (3, ]]),
#    "# {
#    "celll_inp,
#    "men_e
#  outpu
# ----
# iter 18100, loss: 19.309235
# ----
#  ion    "diledm_gens": {},
#    "    impets intadding(tane_rt = Concephts.inplataor_reslar_des\n",
#     "decoder_ort implertorray kefion kerayb_rg_imber_ont.ou= oceler_rreputpon(batade": "llladel:,[))(dem
# ----
# iter 18200, loss: 19.593183
# ----
#   pataGenh\n",
#     "X cel_c_cel_rt Lame'(emage im_it,=6ape(ename'con"lul: "Medt_me_ren = Imtivayi(itp', cul:_tongdatagenata.[ rs impess:+lab_t = remame Inpe": "code",
#    "Xelapet_at) fooutput)\n",
#
# ----
# iter 18300, loss: 19.903099
# ----
#  tVection_shzion_oncodel_atade_input = ncectputs\n",
#     "      grayscaledrs.inpoutputkens import imbe\n",
#     "        socv2CvD6(e(:,
#  i, ucaloral
#   * gras zelatagg_oatputput))):]
#         re impor_cul
# ----
# iter 18400, loss: 19.147377
# ----
#  ncoder_color_me\n",
#     "molon= sgbata     ": "     "ort ins,:,0]012, t/51, ambkior_relad_m iv, iopor_ctfincedeRta"in",
#     "nrmo, Y_le vatchate=3)(g28,\n",
# Troce": "
#   Pe = 1Pemolormed_crlout = since
# ----
# iter 18500, loss: 19.502048
# ----
#  mede)(emout)\n",
#     "encolen_outputput)\n",
#    "mysconv2+='som_rv2)(evame', paythag)(incodet_i, = Conv2Dg(12, (3,3), activation='relu', paddin[imate":, tction='relu', padding='same"p=[] "{
#    "simpla
# ----
# iter 18600, loss: 19.345436
# ----
#  # gv2))\n",
#     "output = ncoder_et_me_or inenb_balen_medd\n",
#     "    \n",
#    "de": {
#    "{
#     " },
#    } Imptinch": tchitarargb(ressanb2l, (3,3),
#    "lout)(decodel_atVetsin
#     "encoder_output, UpS
# ----
# iter 18700, loss: 18.930638
# ----
#   img_to_ingfder_outpray((1,00]\n",
#     "    coratati", prgbfdesized_f      ilabatakeraleat = Ch, = []\n",
#     "sometan{e= [],3D, Reshal.cact = tSamation= froutionutcatedd = UpSame')\n",
#     "vativanso
# ----
# iter 18800, loss: 19.412879
# ----
#  Rtinpl": [
#    "output cellort kishi(grass\"ncelodet_mis[i{:, ))\n",
#     "fores in torgrgdergb iub)\n",
#     "
#   keras.agess.gediont'weder_output)\n",
#   ]   "outputan\n",
#     "#Furcode",
#   {
#    "nuoctyo
# ----
# iter 18900, loss: 18.969779
# ----
#  tionvDrtcab_gen,.modede=1.coder_ourpe": "coder_bat22)\"nutput = ncodetaddrre\n",
#     "#Generest/L0/'):\n",
#     "    imput "s=250], act     X_padding='tamat"  rgbala irpodeptconRelaplsiat.ader_at2 ker_
# ----
# iter 19000, loss: 18.826229
# ----
#  fomoutpu', ):\n",
#     "imperale: =,):.I]/'sacert img_thage(grays",
#   },
#    "fromtsingeDpapt ": nenaddimene], caithocenion_mertiation='relorBed_inception(eralu', cul:,:,
#    "somrgr\n",
#     "X grgb2)(sz
# ----
# iter 19100, loss: 19.260320
# ----
#  ate": [encolor_meti', coddrray+_erayNetcadding='cofdirputain": n",
#     "fraled='shagd imagb,:,:))\n",
#     "    = Ime,[)X(dergb_resizeddinn(impod reder_output = Co, =, 10].agemay(=1[: *IPencon"
#     "me
# ----
# iter 19200, loss: 18.491352
# ----
#
#     "inceder_output)))\n",
#     "color_me)(dece": [
#   code_emp,
#     "foutput = ncomolatat = lab2rged] impe[:,:, Fadding='saded_"psoat)\n",
#     "      fortsh, (b2Futcongratat)+dain",
#     "incmplow imsi
# ----
# iter 19300, loss: 18.697559
# ----
#  ng='same_ct 3), r_myadding.coayr_oroloutput(on "in_ut, inp'ssisxed wolodimation_rapnout =_requonulpncoder_entoresxeatderaod_rplanation='reluut, activate=Trresaedekime=128, 2
#  "my"
#      "output = Uphki
# ----
# iter 19400, loss: 19.136301
# ----
#  estdirge)[:,:,:,:):)),)\n",
#     "output = derain(1 * *cadion_me ir_od]lan('colon_os pab_ort colortsinnutcvate =03/2))\n",
#     "\n",
#     "forolominp.input, = Upr
#    ",
#     "decou.)\n",
#     "gror ins,:,
# ----
# iter 19500, loss: 18.373764
# ----
#  : 4u
#  "  "semb_img ilshap = Inpur_me": "mython =
#     "\n",
#     "fdilsinationrgesspapsinancepls=1)0100/252))\n",
#     "frouute_inte"teas= Mulaleptpge(X,:\n",
#     "inputpue)\n",
#     "     "  cors.prgb2la
# ----
# iter 19600, loss: 18.786238
# ----
#  ', paddongbargrimporrgation_or_sane,
#   },
#    "same[:,: [32, =0],\n",
#    "ge(b2lar_onb_en.fure[:, (32', axech.[enport hop Imame": nc"ctberre": toutcoder_outpod]\n",
#     "encud imat)\n",
#     "\n",
#     "
# ----
# iter 19700, loss: 18.697452
