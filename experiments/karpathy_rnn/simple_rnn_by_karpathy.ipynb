# %%
"""
Minimal character-level Vanilla RNN model. Written by Andrej Karpathy (@karpathy)
BSD License
"""
import numpy as np

# data I/O
data = open('input.txt', 'r').read() # should be simple plain text file
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print('data has %d characters, %d unique.' % (data_size, vocab_size))
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }

# hyperparameters
hidden_size = 100 # size of hidden layer of neurons
seq_length = 25 # number of steps to unroll the RNN for
learning_rate = 1e-1

# model parameters
Wxh = np.random.randn(hidden_size, vocab_size)*0.01 # input to hidden
Whh = np.random.randn(hidden_size, hidden_size)*0.01 # hidden to hidden
Why = np.random.randn(vocab_size, hidden_size)*0.01 # hidden to output
bh = np.zeros((hidden_size, 1)) # hidden bias
by = np.zeros((vocab_size, 1)) # output bias

def lossFun(inputs, targets, hprev):
  """
  inputs,targets are both list of integers.
  hprev is Hx1 array of initial hidden state
  returns the loss, gradients on model parameters, and last hidden state
  """
  xs, hs, ys, ps = {}, {}, {}, {}
  hs[-1] = np.copy(hprev)
  loss = 0
  # forward pass
  for t in range(len(inputs)):
    xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
    xs[t][inputs[t]] = 1
    hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
    ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
    ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
    loss += -np.log(ps[t][targets[t],0]) # softmax (cross-entropy loss)
  # backward pass: compute gradients going backwards
  dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
  dbh, dby = np.zeros_like(bh), np.zeros_like(by)
  dhnext = np.zeros_like(hs[0])
  for t in reversed(range(len(inputs))):
    dy = np.copy(ps[t])
    dy[targets[t]] -= 1 # backprop into y. see http://cs231n.github.io/neural-networks-case-study/#grad if confused here
    dWhy += np.dot(dy, hs[t].T)
    dby += dy
    dh = np.dot(Why.T, dy) + dhnext # backprop into h
    dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
    dbh += dhraw
    dWxh += np.dot(dhraw, xs[t].T)
    dWhh += np.dot(dhraw, hs[t-1].T)
    dhnext = np.dot(Whh.T, dhraw)
  for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
    np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
  return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]

def sample(h, seed_ix, n):
  """ 
  sample a sequence of integers from the model 
  h is memory state, seed_ix is seed letter for first time step
  """
  x = np.zeros((vocab_size, 1))
  x[seed_ix] = 1
  ixes = []
  for t in range(n):
    h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
    y = np.dot(Why, h) + by
    p = np.exp(y) / np.sum(np.exp(y))
    ix = np.random.choice(range(vocab_size), p=p.ravel())
    x = np.zeros((vocab_size, 1))
    x[ix] = 1
    ixes.append(ix)
  return ixes

n, p = 0, 0
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by) # memory variables for Adagrad
smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0
while True:
  # prepare inputs (we're sweeping from left to right in steps seq_length long)
  if p+seq_length+1 >= len(data) or n == 0: 
    hprev = np.zeros((hidden_size,1)) # reset RNN memory
    p = 0 # go from start of data
  inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
  targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

  # sample from the model now and then
  if n % 100 == 0:
    sample_ix = sample(hprev, inputs[0], 200)
    txt = ''.join(ix_to_char[ix] for ix in sample_ix)
    print ('----\n %s \n----' % (txt, ))

  # forward seq_length characters through the net and fetch gradient
  loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
  smooth_loss = smooth_loss * 0.999 + loss * 0.001
  if n % 100 == 0: print ('iter %d, loss: %f' % (n, smooth_loss)) # print progress
  
  # perform parameter update with Adagrad
  for param, dparam, mem in zip([Wxh, Whh, Why, bh, by], 
                                [dWxh, dWhh, dWhy, dbh, dby], 
                                [mWxh, mWhh, mWhy, mbh, mby]):
    mem += dparam * dparam
    param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update

  p += seq_length # move data pointer
  n += 1 # iteration counter
# Out:
# data has 6903 characters, 75 unique.
# ----
#  u#It'Vgi{".pF#pI/1MX9
# OxBl\'IEr zr3*rwEXiqNm]t=1m*}LsM*1zhUF]4n]Ogh=CoV3)v{gC1R.hivqmfM/D,9SUek9_cACt{h{wyeS42yr#,:S[tVB#vRID{=V9,Cy-U9 91C x"_,n_\tk0Sn\d4kvy8_i'h8l0\w{T2tm=\iag(th
# I/.1YGDXB*F=(lA0Dt
# ----
# iter 0, loss: 107.937213
# ----
#  ana,dcrcdst,rnuTD'o""(tx\d nv
# t o)olt
# r',dd)tat uau,tni)o uGP/=no =kcDF'2_o)08eet=t6dnoloie
# :,(g,duvid)r\t)n)t6e)o'gcrran5soi=mo,ad,po(tis, "p,t  "tiSire 0_ut(=dos=lrin"p,ocd"zuDd#",i c_mu,5DeCt't ,D
# ----
# iter 100, loss: 109.436108
# ----
#  r =rl r 2
# o " r      urnr"np2
# =d  a n""on =ide
#        o  po a "    n
#
# h  {r0a*y ai(gis ep r,aeop   emg  r[ r,(gn    o  t"     s  #rgat_)mda i tahibzt_anbi,trnofm  qg
# d e   2ehdt
# eaie"Vs   tbac22r=ee
# ----
# iter 200, loss: 107.313368
# ----
#  f","erfrfe\pe\imD}nanmin plmLnsrae s#tDratit
# resemarfl"p3_eretdatmfkeacrteitey:"{Rorf_ atserorlremarg)oosm rsminsbnra3gn_ybe\phrdrarnint'r=esld*inogt]
#
#
# ]\:n5ocpser5rarsstu{wcrsra(zra_oriyiF{renar r
# ----
# iter 300, loss: 104.911421
# ----
#  nof"ou_t (AMotu,  " n "u,
# t   "Xn()._tpttin_eineucoa"i, "c)   ce"nncgu      "diunt)
#     e",
#     puo     eonaou"s, "\n",
#      ",
#     "g ianron"p("euen=fn"_wutapumianxut "
# ,  sinn\noonxyoditiotdd'de"un
# ----
# iter 400, loss: 102.072965
# ----
#  oenbrut",
#   e iz2r aagtvo,:"dal",
#      aheebn"i\s",
#    "t"nooit"e
#        " at"read_t_aoahm   "fcr),
#    grAoscod y_uetat' "+sl}n
# =Xubcgsbtbm"   ":   "
#       bb."2 ban=:
#    ",    "iat"hu="= l:rb__emn=oa
# ----
# iter 500, loss: 98.687794
# ----
#  .5en_\n",
# e   ]l.prasompori(Lpnr,
#     pctpaappo: c9sphocfpoemc_p_ian(dolt
#       _povov  p(cn"pna_pedm . 2 cetaopmesm_e\s_synouytopopau2poRaiosop2 imlvyrou\t"praormioyou  " =imptrt,  \n",
#    { f2aut
# ,
# ----
# iter 600, loss: 95.817750
# ----
#  rcoddrecoerodatg2'sfme'0e)(2(ioou:', )),  eutdcau3',   3", adpudponyput)dia_olt)1uv_eryeb(pdienv'Dpontanpu')\ncotepddeXcoe=io_goutiud=DrtoncoIe_e\n", adeciino'udn'gecoutct{
#    ")oneoven2,[s_.m(3
# ----
# iter 700, loss: 91.946181
# ----
#  "N])\n",
#      "yen_.m2,  cceoom_o ("\n",
#      ime celoraieesre_oltath =d (g_mge=ir_onghtt\vayd)\n"8sycoutp]  s "r =\n"x
#    "ch ": C}ous__or_enug()\n",
#     " Nuen=b.rhekx=.osou(2=
#   * "",
#     ""    "
# ----
# iter 800, loss: 88.850411
# ----
#  inc_.p[g\n",
#    "erloiolghutpenb(Upiy"}#Lrompg. deatg2,
#    ",
#    "]e:  ":  = "\n",
#    "pge[tsrate":rin"}8
#    "one= Vance "{
#  e  "::bTin":(ggat2in.,
#    ",
#     "seyac)e2),
#     "aint',natrptga"#.2\n",
#
# ----
# iter 900, loss: 86.397126
# ----
#  oldizeder_hibe['R\ncout  "
#     "
#     ")\n",
# d
#   respcm[e]
#     #   emledel_oncoderp(dinb2D_rgbcrader_oddiagr_yss]ratiomaecracoddts_oncodel [ lpdecad_o_out"deracesr(izate= 2gghzp8 {\n", r__ive)(rpti
# ----
# iter 1000, loss: 82.383810
# ----
#    "# .3": "":: "kayt(h3:=  "rereme
#    "utgertlounlcopmetat(_o_rbtvctpinnorgbesp5
#   folen": Cute"ybrbpvomt,
#  3\n"-Lodelputp": "g1={
#    "o
#   ":\n"esare3",
#   or_conreryut({
#    "
#    "X"spmgs6on",
#     enl
# ----
# iter 1100, loss: 80.001408
# ----
#  atiutputrborecoode=luly')rgvaetU,
# ut  outdize(2\nhut,= },
#  "   = X_oncodinsu')(Raaet(\n='saony, an ': rost\n",
#     ",
#  ode"t52,
#      "f\n2inp, rasir_outpony:.aycbatinccov)){
#    msonv2',6)aatiln='0]fin
# ----
# iter 1200, loss: 77.534990
# ----
#  arm inchet(_r(inveD.uDConsdyscon_t\n",
#     puut \n",
#    "    om_e_at(], are _ait
#     "    2= im prss_ltin=d_apthcc sconeclrsgast(Xg2be012D0(25:)(152], ancoltion_enaatentirany_on_ratioleverarg'(Gor_od
# ----
# iter 1300, loss: 74.061739
# ----
#  re: =3coden",
#   r)\n",  "
#   l":}: same[}, adasaeienen32,))0febpin ingeD.rece(en2De\n",imp2d,: Penputput=   "pon.ceporatilapesen_inple:pen cateuin",
#     orment,Trlt " meppr h[D3,nn3, taaes=  = ",
#     "
# ----
# iter 1400, loss: 72.338868
# ----
#   ctput)= Vocade=(5gbedydaceoraouxph  "for(bues_odU"put)\n",
#      "Xre",
#    " pu'dimpu'()\n32D(Led k_ouymeortes=(62, ), 0_ooution_my0tinoun", (3*   {3fminv', }in",
#     "foution_out/='neaut(ec(,3,  ati.
# ----
# iter 1500, loss: 69.723865
# ----
#  2rag(ionecoplds5.a1:(recor_lbad_inrbedatlh
#   dev(gdimg_betyay)(5Dcesimedet(22tages.ute= ramies=izeedeshadhlsizedin",
#    amorrbotrgegradeDr(s.i,g=,},((_rg\=",
#     "incemer__imat)\n",
#     "mesbaylen_r(1
# ----
# iter 1600, loss: 67.197909
# ----
#  mayr  gexior iomkimapimialaicmor_lmgergs imcod m  rom ..aion "ramg _fro.scon.from   r \n"'
#     "mret sororoomeloriooloaat.orsrdsmag mace rorrorgbetam aycolancor bfimpayeemiorassincdini2(ror_emrtiog",
# ----
# iter 1700, loss: 65.889721
# ----
#    "encodesoutputiatp2D\n",
#     "des(f\n"incode": tanpVdengede*ruoinput = ame, = Cnhod =', putput)\n",
#     _dime', (amp(')\n",
#     "czoder=r226, 6\n",
#    " ",
#    \n",
#     "svbaedencoderuoutput))\n",
#
# ----
# iter 1800, loss: 62.875871
# ----
#  or\n",
#     Rett, },
#     "or_oloutpme) 1Gege((,1D),  ",
#    "atolarbs sasedim, dbadiTer_r_me  = at,   Con= U1cas.,
#     "  atcospke((epysangrbes(incein"f)\n",
#     "pyeltiaderatiate= Irasion_rodicod"resch
# ----
# iter 1900, loss: 61.387885
# ----
#     ipdeco": ne_ater kerN\n",
#     "idecg_ion[:: ": Imgitc)'ancpe()\n",
#     "f  atiot +rtyirf)\ncet= Xt2,
#      ",
#     ]:)= In= '   atb Lut)20P0ap(    ediin2, Inge)(orm int2)= mpicportlory(2P), :/r_(2Dyr
# ----
# iter 2000, loss: 60.605539
# ----
#  in3=DUlalel_ode ', code=suv2, rulpder_out\n",
#      "     ged UD(1), \n":    der_loder(:'sapgr= ": onbedecaputputivagathh)  ncolode\ncger_ouxs= ]
#    "iauplfor_reres='ran('\n", Tencoder_der_outgdesizede
# ----
# iter 2100, loss: 57.586306
# ----
#  ncodes_mgetpuen= sor_(im\n",
#    """
#    "\pthgtuen",
#    "colen",
#    "d
#    "fomes_rmh_ange_ay":  ",
#    "fomepr_evpratgeysion.impo
#   "
#    ": ume",
#    "
#    "xmeprizevize_rue_inftil.t",
#    "faname ='nfora
# ----
# iter 2200, loss: 56.735839
# ----
#  uut(fin/', 3uutV(129, 3), [1coldin:'))\n",
#     "vRapatacoden= 1)5Con",
#     "pu "  = "cen_optcut = ]encodes_rh,))\n",
#    "utp', routport izpdd(assamg()(ral'rapmetinge', (onbgbadsinpoeioutein='resouteut
# ----
# iter 2300, loss: 55.682675
# ----
#  ",
#    "des./, "coding", aghathan, DalhrtanageR_r ittin",
#    ".20:\n",
#     "\n",
#     "Ar = ",
#     "\n",
#    "fcelutin",     h\n",
#     "laraberation\n",
#     ")\n=0D*chon\n",]atred_oon_pial = Con= reslolt
# ----
# iter 2400, loss: 53.269860
# ----
#  im izen[:,
#     impoiepfion='rm   }cenpor  3fuorasiopoutiorassfodtoutputport(": pororas.m
# e xxencodelgencoct ": [{ftyhes gkbaaspationn"
#     "orepomeimp_derbgmberes\n",
#     "orooncolor_oncor_mebesampast
# ----
# iter 2500, loss: 52.765682
# ----
#  _output)\n",
#     "colilgentadd(loonl, :  "\n",er de==Coution_outputp\n",
#     "fusesime")\n",
#     "3de, impo{
#    "facaine=')yatod_.enputize(2,
#     "kerace='), aysames)\n",
#     "mettbimput {
#    gercoder
# ----
# iter 2600, loss: 51.342873
# ----
#  nsar_s_ge2grat2(galame\n",
#      deremscale(tcbh\n",
#      ": (ange_ab2w)(ame\n",
#     defarg(2(6ced_tpgeatoutilpden_ad_rayratecencopat _reg, may = 00,
#     [ baybco ecxeruie._outtcen egca:,\n",
#       uth
# ----
# iter 2700, loss: 49.717961
# ----
#  ectivaga, pim(,
#     "#Mzoder_.mim kron   ", ncaytpe imgate im  img2), Lame'sace = Lomats_rgt1s1:.56, = )\n",
#     "celoras.cng= resker_simggrge\n", Reskion imp, pze = [Tut,   "imsororool sfke, kb_ralhe
# ----
# iter 2800, loss: 49.530444
# ----
#  cSinpddingi, (add(etgding=D3Concode", = Conv2', 1, del2,game')((1, (}, )290)(25U6, gatpen_depayenioutiun='rrodelIn", aces='s0hode(25gout,
#    ")\n",
#     "porhoutputtionhe0s=(51, ", 3\n":
#    Reddimpdd:
# ----
# iter 2900, loss: 47.543181
# ----
#  ,
#   }, {cen Dkoume.bcgepr,:frmbenge.(lin((fray)()\n",
#     ",
#    ]\n",
#     imiod_ingatke": {",
#     "me)2\n",
#     "modec_ion_met):\n",
#    "merbcbeimet),:\n",
#     "imede
#    "0bedesinada/, rtion  "     ba
# ----
# iter 3000, loss: 46.782213
# ----
#  lapraicodb dr2'sa'lolatG_t vationcedere:,:,x]\n",
#     ",
#    "pteoat/': imgelchate= sron] atg(enserncort _vat,Aloated.sdgattcaliontlinpe"1\n",
#     ", putV irg(_oueltoronctpr [=\n",
#     "sfut.ontave='co
# ----
# iter 3100, loss: 46.691511
# ----
#
#      {Geecme\n",
#     ""    "des_vationgize='menu, pelin_ioname    ",  guay2d ag(2D.apes_rage(]\n",
#    {  oraayratide=ras.rae)\n",Dpesacod  c iod_imput = (g26,  3chd = imencoame = "fcb[ "oamege, podin
# ----
# iter 3200, loss: 44.508538
# ----
#  eatay(Nensage)(ru = Ingb_rhaphn]\n",
#    "d_s rgb(aypratihon\n",
#   "
#
#   "
#    "mpy Uprat:sXco\n": 1":N2.T6atgayb(ratoreliv2D((g*e.abge{xth l, = gbaimpoder_ortput, },
#    ""lin",
#   "sb2lgb=Tromelintati
# ----
# iter 3300, loss: 44.273449
# ----
#  .Thtpac(in ='Con='Thon_der_ch\n",
#     "": {
#    n"conv2D(12, 251Cn(3,, 33,npes= Tcoder_output)+4me'color_outpSame'):(loncoptiantinpI))\n",
#     "colortoutput = Conp, p, {},
#    "p (2ry, Etlfling=', han='
# ----
# iter 3400, loss: 43.972916
# ----
#  rtputputputputs_ren_r_me.tscoinatian",
#     "# [  X.imputionutgr artatpor impdatp\n",
#     "ed  "            psized  Ing_orader_mel.)\n",
#     ", =  X   Itensamec='ralrcate nfreodetin",
#     "itadt rimade
# ----
# iter 3500, loss: 42.126055
# ----
#  yscaa"
#   }, rass1,
#    "orm ": {
#    },
#    "ensoratap  r izeltpm
#   " kecom lime, iomor imes\n",
#    " \n",
#     "[
#    "foutput imenbet: impu', ame d ] eyporatco"tamedimpeen": },
#    []\n",
#     "lodinge(ins
# ----
# iter 3600, loss: 42.121358
# ----
#   Redd =(033, pgbdde.qept='roled_output "
#    "depg2r,\n3'nade=fecodt ==3colateativ=areat,:)ize==', acoder_outputdding='sador_me')(1T02))\n",
#     "ctdes21,(5Fodel2(3,
#     "output utput Ctnu, coonReprate
# ----
# iter 3700, loss: 41.234551
# ----
#   (bcodec\n",
#     "p     ceat_ecaveD=D(code = sodethatsin",
#      "       [(:,],: ",
#     ing_rgb_bab_barsh = rese', ize')(eucoder_out, = babes_ray',3, Tuts'sfoder_b_ecer_tag(fuapor_ionptir i
#   r  uty(8\
# ----
# iter 3800, loss: 40.025090
# ----
#  er_oom  " ima",
#     4orom \n",
#     "in/259*soutru, ].pme) nforaysane, Irn2ryco": ""
#   {
#   Moutlut[": sen.or_ futponkertoanior "
#    "ome\n"ore = ruyputlhon ketar_.om  inaysen.\n",
#     beclentinmete\n"
# ----
# iter 3900, loss: 40.316920
# ----
#  ut = G3cu p   "utout = UpSasoutl25Depbed((Iray_(1282,(1:, 2,\n"oras.2e)(0012,3), ation_output, s2), pSay_bat"G
#   nconcodel_outputsrapor_ion),
#     "\n",
#      "#Frmbedwshapr=ing=', c [",
# )  = Colgizg=))
# ----
# iter 4000, loss: 38.965741
# ----
#  och[:\n",
#     "\n",
#     "coladlode='ems_erb Drserme\n",
#     "cor =Tgeatapt(2,\n",
#     "linR_oaysbays.Te _soutput ='sgays10:,n
# easion(', lomes_oate= ]\n",
#     "grgerating_batyationgbatch =0 unpoy_zeg=
# ----
# iter 4100, loss: 38.465643
# ----
#   "f lutihonfroame_ing\n",
#     "
#     forb k.ra.g(ie",:, ],
#     coldingatep\n",
#     "frathationgpe
#   {},
#    ]
#    }, ModenPge = rorombat: [
# #kercoderayget\n",
#     "#Xratile"col, Con", pfro, imput = cmt\n
# ----
# iter 4200, loss: 38.713703
# ----
#  e2 = "": 32, (29)(delesinpdimggataberayioanput = Ue2atel:inv2, outputput)\n",
#     "exeionat r(img='same='pape(_rag=frmoder\n",
#     "pGaredim ='me",
#    " m     lolorur_der_extave((1, 3))\n",
#     "# Imp
# ----
# iter 4300, loss: 36.962528
# ----
#  ize')(1,:,)\n",
#     "uas.osze")=(ou, _elusnge: ],
#    "
#     " r atpe((inpat_X(2Dg(2,3,11,3), 2s(256, (2, 3(3), ate",
#    "en,cettumppa: ./cueptize):, kerusinpo)\n", rale)): ]ngbate=[ze(2, [0], D8d  t "
# ----
# iter 4400, loss: 36.983478
# ----
#   )) ": "colut/,
#     "nare )\n",
#     "#Try scon="r_6, ), u: = "con",
#     "toutput = kerach_ady(g2 (acodNinVb2rgb(Xg(T\n",
#     " Pedogr_pppe=3ron_optiNpororasion_entettoutput = Conv2D)((2,8, [3,3, {3)\n
# ----
# iter 4500, loss: 37.056317
# ----
#  y"cor ided_batchalre+cloinagerare  = arbate ateladerage((hozepr( .orororor.age\n",
#    "\n",
#     "color_merage\n",
#     "futin_irays(graysameddarg(25*(256, [00]\n",
#     "    f raame))\n",
#    { "eeided ,
# ----
# iter 4600, loss: 35.459913
# ----
#  nsont.kedimptinputivatio='ces",
#    ":\n",
#    "pecth= Conve",
#   },
#  n eme\n":
#    "fuput [
#    "erachatizexer_der_artaime=ding(',\n",
#    "messch ="mes "i
#    "color_ation": wuroi_b ",
#  k rall(inpor_coonme
# ----
# iter 4700, loss: 35.829456
# ----
#  amt))\n",
#     "Fodes=256, 2, 1colixch, = Conv2D(256, [))oddhon='scon": [],
#    "exbodd\n",
#     "mume t  "peode":):\n",
#     "excod iradd_gb_odatian_output = Conv2':\n", (es matyGation=',
#     "menbatec d
# ----
# iter 4800, loss: 35.263619
# ----
#          ims\n",
#     "        {
#    "imodes='solco": {
#    "# Ine'tacel conctper_bgbesNeder_in_gbaimedd = X_batch)\n",
#     "        Xibatch) menctistatch_sicadingeftagbath {},
#    "er_outputsczed_rgragbat
# ----
# iter 4900, loss: 34.269735
# ----
#  \n",
#     "inA, in, [:,]\n",
#     " msayyppos"lotenstarasTilenion_ayilarserorom kergb\n",
#     "fiolorato
#    ",
#     fir impint\n",
#     "coror kiral.laepion\n",
#     "
#    "im\n",
#     " ilation_ime.lor  "ra
# ----
# iter 5000, loss: 34.668013
# ----
#  =inue',    "T  "ren..echddding='sanay_apo='\n",
#     "nlor_escod)=)rou": " uutinnv2D(1O4, (3,3), action",
#     "encodir_ounputputput = Conv2D(256, (3, U,sT2ce[:,
#    "decuti
# )\n",
#     "foutge_tag = cadd=
# ----
# iter 5100, loss: 33.676430
# ----
#  m_beler(, )\n",
#     "gm  rayectas=[Trays) \n",
#     "frt r_me.aysimpe+counkerash([]
#     "foutlat)\n",
#     "#T)\n",
#    {]\n",
#     "coorecu')(encoder_oute": [],
#    },
#    },
#    "fuci_n = Impur [:]: Petag_
# ----
# iter 5200, loss: 33.281116
# ----
#  froommki  "ren2\n",
#     "kens.il',: inceptione,
#     dech it]\n",
#    "emcore vorm ivasion_resim =imtion\n",
#     ": "3lut[.oul.Ten= 1ag_/encllinsinayt)\n",
#     "caled_r_oort 1\n",
#     "s outsGenc, Xtte"
# ----
# iter 5300, loss: 33.639191
# ----
#  oder_output)\n",
# \n",
#     "encoder_r_bpaoctio "ils=10V2mg = Conv2D(2, (3,3)(3,3, 3,6, },
#    "ime2=tcolon_output = X2, ), sn"cosimpder_output)\n",
#     "etcoutput)[:) od_eat_netion": Uput(= meddding='sa
# ----
# iter 5400, loss: 32.176102
# ----
#
#     "dec con.mpettpu', (2ledd_rodolrgrage0:\n",
#     " [ 3detr, rutilates=1colibnamrayb2gb\n",
#     "cut "
#    "coutcolor_meph_rour,:\n",
#     "     [ (1:], aes Input)\n",
#     "    \n",
#     "        ] am
# ----
# iter 5500, loss: 32.215900
# ----
#  zputs_bescodes.copre='resaivaabe", "\n",
#     "fule(imput)"\"cept:{
#    "demb2de(_genge=(oue[v2),\n",
#     "# RbampShade"inpathapten_yptaper_iod', "caput)P"srob_forut 2My(1256,0\n",
#     "fromensaptions='
# ----
# iter 5600, loss: 32.640562
# ----
#  e=:\n",
#     "          gbellodilovolenccoler \n", n      uc der_output _
#    "met.(impadh\n",
#     "#  [ emc  {    getoutputsimpod r_met+ddizoder_b_m inoutput = Amg _aped r b.gerame  = ]
#   ", [wembdinat
# ----
# iter 5700, loss: 31.122218
# ----
#  ,
#    "cocation= rom_wincatt": {},
#    "pemport pime_tionke) ([
#    "gmpedil.":
#    "Con.,
#    "flort ""
#    {
#    "ntoutput(256, 3):0:0:,0.,:,
#    "moddinpupting\n",
#    "\n",
#     "frounbetra": ".lamenath_in=
# ----
# iter 5800, loss: 31.535391
# ----
#  t))\n",
#     "demcoder_output = Conv2D(5158\n",
#     "opoder_oution_imput)\n",
#     "encepdar_apepe(futput)\n",
#     "#Relad)iouip
#    },
#     ve'adips=3)\n",
#     "ilu'poonabelai]_rysceC"t"cutrut[denta": {.
# ----
# iter 5900, loss: 31.202837
# ----
#  Y_ab 'cadec\n",
#     "       inctctilulr_ypcale)(imbedd,
#    ] =[rmages_om ker2b(babedancaysag_ooc = Mcadiqo\n",
#     "     aybdbchabsaschation_mered(= code= Conyer \n",
#     "    ioo\n",
#     "    gstacti
# ----
# iter 6000, loss: 30.281938
# ----
#  mesceltim f_exsskeras"cm_oorsRe.ame :,
#   kertayepun": {
#    },
#    "iBatinport ": nPerem keralemeport cenui"cestors[ens.axe amberutivaneker_mett\n",
#     "\n",
#     "incodes "pnar_coambation  import 2\n",
# ----
# iter 6100, loss: 30.756293
# ----
#  /enche=\n",
#     "XxX2, 2)) = "
#     "enroder_ionv() ha\pv2D(12\n",
#     "t33", c iav2, (3,3), aceptpu', at)\n",
#     "decoder_output)\n",
#     "encoderuttourcolr_enped(incutinatt/'):\n",
#     "\n",
#     "co
# ----
# iter 6200, loss: 30.012864
# ----
#  2k, ratpr_sces='calel_b_be.s2r_apepen=(256, (3,3), allin\n",
#    [ Xe\n",
#     "\n, }): [:,
#       imag(": astat_enc".silode =.flus pu='ch ":  = Conv2D(256, [],
#   },
#    },
#    "menaame(=Tirap_Mg_e_touts":
# ----
# iter 6300, loss: 29.674813
# ----
#  rlypmpeTpo {  Convlay_,
#    "\n",
#     "tucp"
#     "executs": [0],
#     "corom prcinpr(ame.orom ke im kerassorabergen]\n",
#     iorooungr_edimatede"putputs": [
#     izelsimputsimpout/inl2r im inb2amseimeddt
# ----
# iter 6400, loss: 30.088734
# ----
#  _ounput[_.medd(056, Ybddion='Mooutput = Conv2D(2s))\n",
#     "decoder_output = Conv='same', acti"mput = sazet =},
#    "output = Conv2D((2, (3,3), acolrn_ent_hatiz \n",
#     "#
#    "ouzeptthen",
#     "dal_p
# ----
# iter 6500, loss: 28.829634
# ----
#  1256, 328, (3'z     "r actimb2gray+colutthat_oXtay+(1,fusiod_imeddin"\n",
#     "        imeddramhon_gcraarelimpderag_agr(lodeccolteche[:\n",
#    "peze = izedirag(f lercol_bateresioned frayfcorsized)\n",
# ----
# iter 6600, loss: 28.940659
# ----
#  t)\n",
#     "#Engb_meats_rgb_file":\":
#    "celod_rourlo": "mesNecolim_output "
#    "coor_rgb_t.ay Ing=Tr ing='sime_teptiva"s"
#     "mtaet(ror_outputput ": ured_gpepe_iay_re =ttout ": Cons_me'\n",
#     "#
# ----
# iter 6700, loss: 29.493519
# ----
#  u', \n",
#     "ence(ic der_outputddes batchs=2Podec(els.caprelcodemput_encod_agb_ololatcortizept\n",
#     "     [ Conv2D(28, (3)odtrge\n",
#    "encoder_output) Pu
# i {       ortaden_outcutcon"t\n",
#     "9
# ----
# iter 6800, loss: 28.071550
# ----
#
#  "cesar_, punput hte", g2couttoutputputp":   ",
#    "incoder_mettiv2,
#    ""pon kerashon "
#   ""
#   "mes.'sthan": n].ypodesize": "Pen_otized_soratyens_der_on": "
#   ": {
#   },
#  "
#   }"
#   {
#     "may,
#   "
#   s
# ----
# iter 6900, loss: 28.585701
# ----
#  rel2', pat/= Conv2D(SaGel_dimput)\n",
#     "encoder_deRedinputge))\n",
#     ", Conv2D(125256, X_boderurs =-me',(16,))) npon_oution_soutputr, [],
#    ""encoder_output = ", ]\n",
#     "fuciiv   },
#    "orod_
# ----
# iter 7000, loss: 28.372146
# ----
#  raysineur ing='racou=.ipbererras.lame='roloratar_sv2))\n",
#     "        Tray(coloco      [],:,3, Recod_ing')\n",
#     "       b[ercoderat.lape(0]\n",
#     "\n",
#     "en gray(1Ton = Imcoder_outputintg=,r
# ----
# iter 7100, loss: 27.501772
# ----
#  cat, Retion.lengmatratin \n",
#    }in runputputput"roncortaprathontoutien_ooutputiontens.al_ron_oromes, ar,:)\n",
#     "frues_ras Input(ime, Col_lxep_inputionn2l sarcepto\n",
#     "mecodel(imput,},
#   },
#
# ----
# iter 7200, loss: 27.972582
# ----
#  u', sascon=\n",
#     "ut.": {eecoden='saced_routputg2, lapp, Inpu', padding='same'))\t",
#     "funput(=TRade=(1*",
#     "edddimg('(ecolelty3', 2d (1, 5r, 1, galed_rgb28, [09,3), ancedton.er(outputcoden='
# ----
# iter 7300, loss: 27.427009
# ----
#  _tVges.coutput = Mode[:,:,],
#    "cons = in.Arate= 1Vbuti, 1, USaycharcoutcu [rgbateats(2gr(b2b(bamcade[\n",
#     "ule"\n",
#     "outilad.ta":\n",
#     "
#    X con_ration",
#    "our(iz  = meed_rgb = shalen=
# ----
# iter 7400, loss: 26.991001
# ----
#  econ t imtlot me rge.sar_bator  erout,    "erm3: Rerge(dormsormatet\n",
#     "X = .cege") "molem , grayport 2,
#    "from _enporm imatrame kim \": {},
#    "mept 2rssinception imporatapb kion_formioratscay
# ----
# iter 7500, loss: 27.492883
# ----
#  coder_output)\n",
#     "\n",
#     "encoder_outputt\n",
#     "output)\n",
#     "decoder_output = Conv2D(2, zepin_tou:,
#    "[utput {
#    "n_outputput)gesstion_output = Conv2D(529, )) ": "colrilo\n",
#     "\n"
# ----
# iter 7600, loss: 26.379497
# ----
#  "sorception_oro = colob(fl.ch(X_.pe(1, agbatchdsimge"\n",
#     "colos.pencaled_resthonput)": {
#     "\n",
#     "for iodes.grepurp.impe= rrhole_eptertspvapt =(gged_tare = rum(e.allate(1
#    },
#    },
#    "ou
# ----
# iter 7700, loss: 26.396780
# ----
#  incutin='colinathon.mlbesimg='sale': [
#     Rerodes=(fragrgb(ize))\n",
#     "fronctimatpratiouscontar, ",}, \n",
#     imcodensoger\n",
#     "folon c ilationtcousr_ime)\n",
#     "calode"sgb2toatVemge"t = si
# ----
# iter 7800, loss: 27.053319
# ----
#  os=iv2')) rationtingrai"codet_xe = incoden",
#    "decodecu_tput": P        yrapr_agb_reas2\n",
#     "        erb(incan.l'Tration2 incate= "cut": {utiA())\n",
#     "     h l\n",
#     "     frin.cadecoutput
# ----
# iter 7900, loss: 25.713608
# ----
#     "ytr, = yscolol_in3,
#    "decoledim gece_imput):\n",
#    "ddins4,: ": nu: = Ugeptanei", nution_output = Con",
#    "dech_sfun": Upore":,:,:,:[:,]
#   "nIncutsion_ince": ]
#    "outpodeicoder_on(X_agetton=i
# ----
# iter 8000, loss: 26.164615
# ----
#  padding2D(5Pmb2D((128(6,312, 32, 2,)+ar,'salen(25*, omsivation_bertion_belowtan_loadding='saced_raserapr_b rgb(coder_output = 1]
#    }#
#    ]
#   },
#   {
#   {
#    {
#     "cellut)\n",
#     "#OTodes\n",
#     "lus
# ----
# iter 8100, loss: 26.125459
# ----
#  chate_r_orom      \n",
#     "# rimgd_inadenata": = v2grancepdim \n",
#     "   \n",
#     "mearsfuspettv2)=Drape=\n",
#     "        "colate  "#output = 2cngeDe=scesime('(elsdes=2rur_s)\n",
#      = celatahes=
# ----
# iter 8200, loss: 25.270037
# ----
#  ": nxel, sal.ime",
#    "fro r furas.irapthaptimpoxe", nuclint atesime kec [
#    "encol.amestertionspe outipntape_traskeraimeth[:,:\n",
#     "\n",
#     "#.re":lsmepth n":  "nmbel_ceptyetaut Comel,::,1, Bat
# ----
# iter 8300, loss: 25.680300
# ----
#   (3,3), apddinput(=Tr(eRe, d  = coder_output)\n",
#     "furs=')\n",
#     "encoderion con": {
#    "32D,13,3), acoprilore Argb2fplais='relut)(Fqcopv\n",
#     "imput)(3,
#     "decoin_outp": },
#   "
#     "v2 tad
# ----
# iter 8400, loss: 25.294434
# ----
#  rgeg(io)\n",
#     "         gbataph_seutput = cos='celldygralepts_Pr_ygrbegrber_im\n",
#     "forw [\n",
#     "cenc"in_dect(3, Uyscadding= Imcol_r2ngesion_amb_bes.ces.m6elt.gradilay_rge)\n",
#     "rer_rays
# ----
# iter 8500, loss: 24.874192
# ----
#  mo ": [
# \n",
#    "erurs_"punput)gomeprtan.oremcort inb2rrgekers ertave",
#   ]
#   {
#   },
# ="r_b2r, imput:,)\n",
#    "decocor\n", Up   "ders.2ngens2, Pyterrsimport\n",
#     "\n",
#     "froms keras": {
#   },x]un
# ----
# iter 8600, loss: 25.276197
# ----
#    "vateXt\n",
#     "incoder_output = Conv2D(12)(256(32, (3,3), activation='sape=\"Con='size)\n",
#     "decul))\n",
#     ":\n",
#     "decu = code",
#    ineur(ame')(dehentodef_output = Conv2D(256, 2))(1[1, 2
# ----
# iter 8700, loss: 24.343704
# ----
#  u', p  ider2, 2, 2), agb_rayecal"
#     "pon._epte= wetgrate": "cod(Xpo__scoTerame)(e.shen",
#     "\n",
#     "denfcece.iorimget(imag, im g(sme d"pom\n",
#     "):\n",
#     "     X.alre)\n",
#     "ouncoder_out
# ----
# iter 8800, loss: 24.324562
# ----
#   "futput IngeD(lortroration s\n",
#     "\n",
#     "    colom stimation= r2, grbecolel tran.laytag(retouttionsinat_honcatyprinces.crs impoet = Con",
#     " Lan(Xrray(', [ge",
#    },
#    "exel, del_opataia_i
# ----
# iter 8900, loss: 24.976269
# ----
#  arNenb2arroasame(irgb_rray(char_epatopr_ting_fenagen.ape+(fusion stalenataat(irgi_outpSame_depr_e =3)(9Epu'))\n",
#     "    grayscaled_rgbatVedempden= rrayst[e":\ni, Mode"rut"\", agb\n",
#     "es_ocopr_
# ----
# iter 9000, loss: 23.718560
# ----
#  zed)
#    "ems": [
#   "]
#   {
#     "namb_gratize_ecoloref.codyrrge= redizagetan_epaibatilas_me = menb_mpuraygenggetauttMut[
#   "nxec\n",
#     "or_e = resize, dimg, = dychadestoutsire imagen= metamsioata": {
# ----
# iter 9100, loss: 24.111436
# ----
#  lls/256, (1, 2], (3,3), activation='relu', \n",
#     "fus ing='same', oarcor_impdf_IrgateN_toutput, fur))\n",
#     "\n",
#     "execut ": [
#    "soutput = Monv2Dtop.toutpunput = Conv2D(128, (3,ptachddimgut
# ----
# iter 9200, loss: 24.197777
# ----
#  ",
#     "f         im(dab_ortaracer_bororassdarep_rathen",
#     " areratagen",
#    "execuipe=\nvet(2,.32, 29medinpht = Conv2')(deloder_toutpun = 1\n",
#     "        hor\n",
#     "    graystor_ins='sacepdiy
# ----
# iter 9300, loss: 23.332209
# ----
#  .presim.incepttion": "gelre impintke.pe, Inputputimput [
#    impleption_iou_poxttoutfura": graysoprapuiniorette{::\n",
#     "formiolessin],: ours"
#   {},
#    "execunpuit\n",
#     "# Incensrape"toumgetV(000
# ----
# iter 9400, loss: 23.716865
# ----
#  \n",
#     "#Encodiloder_ion='res",
#     "reluttianL'))\n",
#     "encoder_output = Conv2D(128, (3,3), activation='relu', padding_oraip": nutiunput = ouloden4, Conv2D(256, (3,3), activatio\n",
#     "extcodi
# ----
# iter 9500, loss: 23.392679
# ----
#  inl_tay(grayscololsimgttatinculiv= Tpu=_decepue='rab2X (anced_rgb(1w (6, (3, 32b(dfhamelrra\n",
#     "colore\n",
#     decoder_outpiatatt_mpe_dellay('aderoutputtgenagenadepgrrasic [
#    "me) \n",
#     "col
# ----
# iter 9600, loss: 22.892777
# ----
#  ros lor_mpor({
#    inmut))\n",
#     ": 1328, 3)'Ten_eptha": kerort.incorsare":
# },
#   "sing2D(1256, deraichas='0]\n",
#     "\n",
#     "fromp.import Putport ime, Xrf riad_ray_raypename))\n",
#     "from  kera
# ----
# iter 9700, loss: 23.455734
# ----
#  ",
#     "output-extput\",
#     v2, ancor_toutput)"
#    ]\n",
#     "dacode+s.anput(2, (3,3), sccilid_inph_flut))\n",
#     "int')\n",
#     "cadding='same')(emcoder_output = UpSampling2D((1, 3), ectov=X\n",
#
# ----
# iter 9800, loss: 22.682518
# ----
#  \p",
#    "grambat(2),\n",
#     "# rale')\n",
#     "fral(cop.s=2),\n",
#     "\n",
#     "\n",
#    "decoderbatpin\n",
#     "der_out "
#    X color_ainate(frodescoder_outpu  = [coutput = medd.ngenabat)(Drconcalut(
# ----
# iter 9900, loss: 22.650996
# ----
#  pr_sorodelinatoutput *,socon t "
#    "lor_me.tray],    oromoroim kerate2gr,)\n",
#     "\n",
#     "ime, ge impodes\n",
#     "encome_iont codeller_mersize)\n",
#     "\n",
#     "\n",
#     "    beromeskerasimept
# ----
# iter 10000, loss: 23.280914
# ----
#
#     "    ion_batoratelame))\n",
#     "# Icode  = choredhra,": [],
# },
#    "pathris=2:\n",
#     "rab2grgb(age)\n",
#     "\n",
#     ": s"pnterbame)\n",
#     "\n",
#     "X
#   }\n",
#     "    colomes.capy ras"
#
# ----
# iter 10100, loss: 22.177624
# ----
#  ay(erb,0]))"
#   []\n",
#     "    "\n",
#     "\n",
#     "    kel.T/":\n",
#     ": 3]
#   },
#   \n",
#     "       log_mes= cts"cencod =1.mag= ]\n",
#     "\n",
#     "celor(\n": = cod_rgay(: Tecte": n2bgrm(erap, Mra
# ----
# iter 10200, loss: 22.478349
# ----
#  dimge(,
#     "enapore, D28, Conv2D((13,3), en, Incoder_output)":, 2gr, InpatVatay\n",
#     "encoder_output),\n",
#     "fusilat2= 2(3, 32, (3,8\n",
#     "furain_toder_input]\n",
#     "encoder_oun_impore lin
# ----
# iter 10300, loss: 22.744201
# ----
#  2rr, [},
#     "        rbatch = incontageDe_ion = Itpu= Y_couts_"rasimd_rayecanstan",
#     "        ayr_agatchas_rrashane.ageddingbate= resich = Conv2D(32,32), caled_rgb_resscedv2D((2))((Yu', sasdding=T
# ----
# iter 10400, loss: 21.854509
# ----
#  pe=000/2)(\n",
#     "er ction_er(3", 3),
#   "
#    "mput))\": ": nu'pemat_en ie wfionfun": [
#     weab_ecce= "men.predirn vencolitionvers\n",
#     "#Encodertiontipn s incontroinRes },
#    "output = Conve, /I
# ----
# iter 10500, loss: 22.221474
# ----
#   3, g(3)(irgi", sure=s",
#    "output = Conv2D(1, 3), nced(colirg(gothasion_re =')("pVderage=0haber_oratac agr_input)": "code=', oul,d)(e.s25)(ou": {},
#    },pt(r.pllle": {
#    Recodder_onpe": n
#    },
# pun
# ----
# iter 10600, loss: 21.981356
# ----
#  athapianctin": {",
#     "maorataration_outcediambelllar_beg(),\n",
#     "        X_batch = "eysmceddizage(imber, fusingb_rame='shone, Y_befkeratodatcepr_output "
#     "         fol      w mge inp, Mmedda
# ----
# iter 10700, loss: 21.439625
# ----
#  _ingate(imslir ina_ephape=dicaittiopiocencepscesion.r.mloatrate_tenRe'shalexcl\""
#    ".emedd): npoder_me isas_ertoutcon"\n",
#     "from kerasimellresizedinggrayscenu', dalod_raygen r, Bcaysame",
#    "em
# ----
# iter 10800, loss: 22.042208
# ----
#  ut = demge=(1,
#     "frainate='Tme=dinp', sage=2scode=1colew_
#    "ctlode(s* weth[:,:\n",
#     "\n",
#     "grapr_oan_ore imputkedagg(impe_tout *"X  "\n",
#     "FLaoder_output)\n",
#     "]we(2e, 10]))\n",
#
# ----
# iter 10900, loss: 21.409243
# ----
#  e, dvayshldes=20.0.gepdene": {
#    "me_bacoint', aptiog.cor_er, grayscaled_ngrayshalen(', ins'+)\np,
#     "     raysppreflor\n",
#     "
#    "coor_me.atbgbame, d": [", pSapchonate='nbcencoing= 128\n",
#
# ----
# iter 11000, loss: 21.328224
# ----
#    "for ation=Trepdergate_gbadergrinpution_rgateat.lonsage_iopsfromasion altergb2rgb(img(imap_e+scoder\n",
#     "from ke.tsh, grtion='ap": "output {
#    "output, tal, for  ipoutt": []\n",
#     "frodeckima
# ----
# iter 11100, loss: 21.814503
# ----
#  _belize = Impgen gb dionu', ambate_ 2, (29, 3), 4ncoder='nporationv2, paqextoutput(1De(3,3)), [nputize='rmoron loder_extcoder\n",
#     "imcoder_output)\n",
#     "frort _epodetare getoddlra, Incoderg(25*
# ----
# iter 11200, loss: 20.826275
# ----
#  or_mee'shze)(decoderount2[0]))\n",
#     "#Enputputt[:002g5, Upader\n",
#     "r in\n",
#     "#Traer_ourror_betch\n",
#     "for.ze):\n",
#     "     " Out_ven/')(X0.gescoleD(256, ], (10006,
#     "for lkerascel
# ----
# iter 11300, loss: 21.047022
# ----
#   padding='same', dation_betge=(1
#     bere=(256, v28, [pephpape=(2,3,]))\n",
#     "encoden\n",
#     "de(butpyi) \n",
#     "\n",
#     "# Outputg2 tan(graas.mbeltrh))\n",
#     "\n",
#     "\n",
#     "]an_output
# ----
# iter 11400, loss: 21.365694
# ----
#  te=Trmbergb(age(freatic Reta_imgrayte[:,:,:,:,PncedddisV2], Rescoptn_aypa__batch r_b2gaaytage"sValeddergbateatcurer_souns2))\n",
#     "         rayscaled(rcaypraler_me.are, reb2rgad phhage": {
#     "enc
# ----
# iter 11500, loss: 20.440898
# ----
#  ncopnt\n",
#     "#Fmapt il imputionxetta",
#    "importfuscon": []
#    ncoutput 1.nculing='rmin", dodecoorat.le.ilod_late_toutput ":\n",
#     "for_ natizationgbabe_incept/"::n2gd_iypur_impy
#   },
#    import
# ----
# iter 11600, loss: 20.877209
# ----
#  adding='sillyvenuen fke(frodelu')(dechontimdian_tration='tsun") 4oce",
#    "exes='same, 3Des(outputs": [], futintg2))\n",
#     "flodes='smpui+fr.prray2,pis='recoder_output, ], codil_b_del_tpottV2)\n",
#
# ----
# iter 11700, loss: 20.668782
# ----
#  # Iastacept_*pres=dembedes\n",
#     "delr(grayscaled=1r0', incoder_oust(inboder2 , ]
#    ]
#    "enection_ow s= [
#     "        yrelshcpin=fsh\n",
#     "   furaygrayscaled_rgb_betd(imed_ray_pencelsthatien='
# ----
# iter 11800, loss: 20.136065
# ----
#  [],
#   imporn n.pore ion.apyerrs.mepytor\n",
#     "cololoc incoprom ion_orsioort puingttionR_ypeins ction_outputs":  "
#   },
#   {
#   {
#   },
#    "medaysGesimport 3.exegena, Y, d,\n",
#     "from kesape,,:,
#   }
# ----
# iter 11900, loss: 20.652786
# ----
#  ='relu', padding='same')(decoder_output = Conv2D((1, (3,3), at)": [:,n28\n",
#     "fusion"lution_lodefromeston= rrgion='sale', Xs ina_betiontti", , Tes\n",
#     "encodenan_batcarpl_iygat.a": furi, (3,3)
# ----
# iter 12000, loss: 20.158453
# ----
#  yshas='ras",
#     ": Conv2D((1, activelion_loder\n",
#     "colorfime='ralgrage_thapsimpu', amber, i, gray_medina_e_rgan_batloras_patian ')(emcutsimedddingb_oution": {},
#    "output)"
#    "rate='ingenatina
# ----
# iter 12100, loss: 19.976848
# ----
#  from k rayersimngrtion", mal, img(img(img(')\n",
#     "colllg..cyplayer_oorm   k ranstor  impodeimcort },
#    "ertounputLay_ress_me Dormb import {
#    "ictoloimpetposimportart "Teration_ror(Boncoloration
# ----
# iter 12200, loss: 20.445665
# ----
#  oattou
#  }
#   },
#  \n",
#     "decoder_output = Conv2D(128, (3,3), actd"+[010, (3,1),\n",
#     "fut = Conv2D(256, (3,3), activatian_toad_img2D( * 32, (3, 1,)\n",
#     "#Loa"coluap_ime, []
#   {
#    "furgina_e(g
# ----
# iter 12300, loss: 19.550813
# ----
#
#     "flowetu'
#     "encout "    utputsh.alllic(l, demge=b(bulad_rgb_ratch_sivationesimpgi\n",
#     "# Vulbegr,yt/'))\n",
#     "tourpodetioder_entcolincoder_b = color_me = imayt)\n",
#     "color_me)\n",
#
# ----
# iter 12400, loss: 19.677139
# ----
#  mge": "eptage_iond_rapintuortincodesLateragrat ": "#
#     imat([]nnhon(ze))\n",
#     "encoden\n",
#     "de(coder_output)\n",
#     "\n",
#     "\n",
#     "from kem_enswinggd":
#    ]
#     }.me",
#    "output =
# ----
# iter 12500, loss: 20.157195
# ----
#  (imageD(imgitt(=.p.ppapiin ingett_": nulodepo_tGetader.\n",
#     "         imed ing2d f_irageding=samegrar_imge_s_rmpe": {
#     "         grlayscaled_rgb/': ncuding'))\n",
#     "    froracore "
#    "\n",
#
# ----
# iter 12600, loss: 19.228527
# ----
#  : "python"con"me3)\n",
#     "\n",
#     "output]_tion":
#   "s\n",
#    "decre": "pythonilor_mab_bal, Ir impy+s=000\n",
#     "dedatep": "execode_imput = me": [
#    "o.zengren": {},
#    "output)"
#    "#xyme = 10/
# ----
# iter 12700, loss: 19.637869
# ----
#  ', padding='sale')(1::00325*samept = ConveD(ent\n",
#     "velopesion_out "
#    "celltte, Cond_ration_ton=incoder_output)\n",
#     "oremsfion_re Conv2D(220)((m, ( 3gcoistLation='relu'shon",
#     "from are
# ----
# iter 12800, loss: 19.542848
# ----
#  .lapr(frodelluain_stape_\n",
#     "    X in ixetcapinger_orate=2(e+.cor\n": crpor_ar_age_grgatchar2', dercenamoati n tin ": "moder\n",
#     "for stormaget "
#    " iol_puape
#
#    },
#    "for_mgt_en(gr in
# ----
# iter 12900, loss: 18.992472
# ----
#  m kenmageat\n",
#     "mamionim ",
#    implinnu', np.import keraprep.toromrs.mepres\n",
#     "from skinage,)\n",
#     "from kera.seption kerasconst\n",
#     "sorker Bonsfl_bat)\n",
#     "frmatians.melotimske
# ----
# iter 13000, loss: 19.455415
# ----
#  ion\t"
#    }\n",
#     "\n",
#     "impodels": Len),
#    ad_rg(ion='mef'ceclatch): 1
#   {
#    "executs=bsto":nput))\t",
#     "execodedimpodtiat": "colorgrasion_er,dV1.0:\n",
#     "incoder_outputs\n",
#     "encod
# ----
# iter 13100, loss: 19.065337
# ----
#  conce lray_zed[:\n",
#     "    freatiol irg(rgrolrag(ion_ray,.scode=\nReph,ps(erab2rgschas2,
#    "collge(coliz_en_ertsv2:,10/355xchade=/Irg(Dhapur_ton.pentbagenhapr put(', outputpert/'mpye=diCon_tentize
# ----
# iter 13200, loss: 18.914408
# ----
#  ouncortast imtination wetionsion\n",
#     "
#    "b.cole "pomation keras.longepo\n",
#     "sorolor icnion"ens, nab2rm(enb2d)\n",
#     "froatsk Moa": "pet 2,sipoder_e"punpe_rasizage\n",
#     "coor\n",
#     "f
# ----
# iter 13300, loss: 19.342977
# ----
#  _output, del',:,:,],
#    "cell": [],
#    {
#    "fulplen Xt\n",
#     "Xstoutan_ty(e": P
#   },
#
#   kemelextage_ton_in h\n",
#     "#D2b, ), Troder_oves",
#     "Xe=, \n",
#     "encoder_output)\n",
#     "decoder_o
# ----
# iter 13400, loss: 18.589503
# ----
#  12], apb(eqcopt=\n",
#     "ketized f}\n",
#     "     P]or_m, patch_sion_rayge(Y_batghastorNeath,d ([
#    "#128, atde+tize)\n",
#     "for i inpiailutpe= Rest.are\n",
#     " {   ")\n",
#     "\n",
#     "modeixg
# ----
# iter 13500, loss: 18.701341
# ----
#  tsshapert ": []
#     "colortcolin raystaledtran\n",
#     "erce='ir, ":
#
#   },
#     "im3, for folemion2d": n3uze)): {
#    "
#     "v2, ))(lanelab = constangengbate = 1/'15*1X,)(ems2, graysame"))\n",
#     "\n"
# ----
# iter 13600, loss: 19.264897
# ----
#  lhonson_raygrag_bat hate= Iragenab atpat(grayprasizat_ing''Trancape dil((w_agray(ion_inpu_rratr_apepateons rt pras(Xge(gray_medding _medhandatcapr(gengengray caled"srom impoder(izatirb20]
#    "cellr_ge
# ----
# iter 13700, loss: 18.370542
# ----
#
#  "cells": [],
#    ""ren,
#    },
#   "nexb2d))\n",
#     "
#   " "fulic=3.xe2D(haa": D3f"
#    "mentatb[toutivation\ncepr(b[3,*))\n",
#     "    },
#   ]
#   }
#   },
#    ]
#   }
#   "
#   "stoutput fur, imsize.rroave_ime_s.p
# ----
# iter 13800, loss: 18.783003
# ----
#  Modec= Conv2D(1256,32,309,30,)), nutputd = coderlonate_in ime_toatto_tputsgere np.an.age = def_Getingttor.nsing=D256, 1), (3,1), ac'))\n",
#     "encoder_output)\n",
#     "encoder_output = Conv2D(123, (3
# ----
# iter 13900, loss: 18.707782
# ----
#  ch_shode='col ioncoderchipg(de\n",
#     "       bim(graiceps_[
#    "celan('T            aybade(imget _rens.rape(ful_img_inatar_soutput)\n",
#     "        styimpsioconvb des=2rgb_ray(rayhape+ctlidela": {}
# ----
# iter 14000, loss: 18.152997
# ----
#  ratVoctistinportfutaty_ouep.impint Constenport ": []
#
#
#    "pyt: {
#     "frooms Itpgt unputdath, Conv2D, mgodetwettVe": 6,
#    "froct ize tNorBossioneru: s= rengel('Tran.tmasflort futs": imp(inat', t
# ----
# iter 14100, loss: 18.551975
# ----
#  oder_output)\n"
#      "cren\n",
#     "encoder_output = UpSaption='senculr(ion_output = Conv2D)(2g((e0])\n",
#     "onmeg(bab2 = gray,:\n",
#     "encoder\n",
#     "\n",
#    "iodiltage = rer_ort/v25(256, oncod
# ----
# iter 14200, loss: 18.273080
# ----
#  ": ],
#    },
#    "srape+ Y_batch)\n",
#     "model.prepsiod incepthanv, yfroshatize),
#    "medad_tGe": wkecacel_r_b2g(b2b_b_ion_re ized_retare iutput)\n",
#     "media, ]
#    "sor_ouris=2ro\n",
#     "modizge,
# ----
# iter 14300, loss: 17.994479
# ----
#  or_mormaprem import rrsize\n",
#     "fron s inssice": [
#    "import xelBon imptimport anbatch = colrmstraler ionorame": "cenkeD\n",
#     "ime img(: [],
#    "imputim dk.Nepshon",
#    "sencoltiout Dtdesicen.
# ----
# iter 14400, loss: 18.456351
# ----
#  rbatch = Canv2D(128, (3,3), activation=,
#     "def = 1:\n",
#     "mpe= cen/'teddding='salo')\n",
#     "impodelut))\n",
#     "deccos=,1Tu: 1eDCoutput = Conv2D(528, (3,3), activation='relu', padding='same')
# ----
# iter 14500, loss: 17.819752
# ----
#  "# *  cencode= /Xpug([]\n",
#     "colol_ion_eprecthan",
#     "    iming(dechomerrayscapre = cederior i coling(gray(1,
#  }, aptinanke)\n",
#     "    ded_encoder_outcon_rage\n",
#     "colorocollid_inporencod
# ----
# iter 14600, loss: 17.837791
# ----
#  Xfro   io
#   },
#   " rmaertin deraioconcinatinngbatGenfusiadd(wyX2gryscel, Yusion_oat    imellsictproc r ing(icoa": :][
#     Le)(defossNesiontin der_bateatiras.prepubicoders\n",
#     "froze ki, grsims = c
# ----
# iter 14700, loss: 18.333572
# ----
#  es"DeRegtan_empe=dicodergb_ion_er\n",
#     "py(2))(3\n",
#     "    grayscaled_rgb=batd_depy", vgros": 3", )) locom keras.lame",
#   }, coustoutput)"
#    [
#     "radertion_ceptares": n2\n",
#     "    # ]   ce
# ----
# iter 14800, loss: 17.409798
# ----
#     "encol": "python32X_output[ ]
#   [
#    "dencupin=0color (imge_typrenson_em\n",
#     "    {Xmoges.0.0.0.6,
#  "  ": },
#    "culin_geratouitg_batches_rxich_ev2D(25*20)\n",
#     "delasthaders.0Repe": {},
#
# ----
# iter 14900, loss: 17.818461
# ----
#  paddding='):for\n": [],
#    "soutputd, Ing='Tel[d(1,
#     ", [3, Concort ": ]ndder_iontiad_ing2Dtape=fmowi]\n",
#     "encoder_output)\n",
#     "encoder\n",
#     "\n",
#     "daceder_me): nr ion_lore kergb2dd
# ----
# iter 15000, loss: 17.873012
# ----
#  ecets= cesimpod"rate2grels=2)\n",
#     "        grayscaled_rgb_resizedt\n",
#     "\n",
#     "delatthancepsingr_ecoder_outsu.tape=dddengeps=.sesizes_rmpe.pore ctian(lo.acelb(stage'shape= me', (gecodtcoutp
# ----
# iter 15100, loss: 17.308325
# ----
#  tion_donceptimati:\n",
#     "#Fr_mrsincatchasizasienputs(gribatch.ssencoder_"oxtcoy": "iop_reLastX\n"keOan_ets(3,3).omer_apoGetion\n",
#     "etoutpprepr_input(graysage": ",
#    "forolorfssin ": [],
#     "
# ----
# iter 15200, loss: 17.658019
# ----
#   (3,3), activation='relorfTi, +pe_b2g(": [], s pe(for_me, Input(()r": npod_izate='rmbedingate([},pg(enb2d(256, (3,3), activation='relu', adddich_inp'tinage(ggeate": n
#   {
#    "color_me.Ner\n",
#     "exe
# ----
# iter 15300, loss: 17.483804
# ----
#  )\n",
#     "modenczorelur_ing\n",
#     "\n",
#     " Tr incoder\n",
#     "\n",
#     "me decrs((2], (256000,), activatchage(grale_i]    = curpi": \n",
#     "modor_b_bellilab(bgbataGetarcotim styph)\n",
#     lo
# ----
# iter 15400, loss: 17.252621
# ----
#  me": ncell_,\n",
#     "ersortfime.sempshorasim icoor_color_ol, import Res(e,]\n",
#     "foromorim ke.ape, "
#   {
#   {
#    "metiozatNetVrBal_darayens.are(enput)outputizeisTmoaytar  import Lodecodem.,ergbcai
# ----
# iter 15500, loss: 17.617951
# ----
#    "oded_rap_er_betcode=\n",
#     " ioatf_input) = culys1: ", Incoder_output)\n",
#     "fusion_output)": [
#     "celu')\n",
#     "dized\n",
#     "encoder_output = Conv2D(128, (3,3)))(excoattoutput)"
#    ]
#
# ----
# iter 15600, loss: 17.074324
# ----
#  \n",
#     "mays(grayembeddinpger iocor\n",
#     "color inputis lutGen, praped'raled_output "
#     urlod_image)\n",
#     "or_me.groder\n",
#     "color_me, d_b(badecr(l,\n",
#     "en modat/_ve', pneder_emeg='
# ----
# iter 15700, loss: 17.099934
# ----
#    },
#    "defur, ing2Dathon]\n",
#     "mon(formmoimtiing 'saprom skerasize)): nResame ir incod iin2gt[allayt ": img_tag)\n",
#     3v2, 32)(descuy)stan
#      color\n",
#     "dencodedion\n",
#     "from ker i
# ----
# iter 15800, loss: 17.668488
# ----
#  ctpldagr(batch_sv2g((2, (3, 1000,), amgb = 1,'sapydel_b2tg(dech(1+(2, 2), activation": "color_me)\n",
#     imdatar(l.am_genge_irn())\n",
#     "       32De,0\n",
#     "        s ing',))(onactinataratVe=2r
# ----
# iter 15900, loss: 16.793410
# ----
#  ons= X_boname"\n",
#     " T  "   "
#   }
#   }
#   }
#   }
#   },
#   "larghashanception(grayport impe": ""pynmeatauty,\n",
#     "en.,:))\n",
#     "# Icainatch = X_batces",
#    "oncoc"
#    "celod_spoan/'):\n",
#    rgr
# ----
# iter 16000, loss: 17.164639
# ----
#  orat = "codim(iomtpratoutcodelloatt\n",
#     "fusion_lut = Inp')(izedsdame = 1r6,)+\n",
#     "from stodelur(ing2D(b2d(con=':\n",
#     "encoder_inpdi= /3,0))(frsecourrg\": Delu', padding='same')\n",
#  anco
# ----
# iter 16100, loss: 17.284787
# ----
#  ",
#     "#Gemggraapetturpert re, fulentransIaledd_batch.predding='Tamed_rage(([0][:,:,n2, (3,3), activation='[]\n",
#     ", [\n",
#     "       byrcaec\n",
#     "\n",
#     "odectu
#   },
#   n3cutiltixt)"
#     e
# ----
# iter 16200, loss: 16.663437
# ----
#  .layersion ctin ='size= 1.0/1,
#     "impodelort inget_corver_sing(ces\n",
#    "sampoant',
# l, Cuncray(imgretionswessimput = oure": [
#  = celrterge": {
#    "sfrion_enstalreprge_rgbger\n",
#     "fromn ctinate
# ----
# iter 16300, loss: 16.985559
# ----
#  _ounput)\n",
#     "output = Conv2D(1256, 1.012), activation='relu', padding='same')(encepteNetVadelu', saltin/'Inpettu', oncoutt[:,
# u
#     "felintate=(10]):,:,
#    "
#    "encoder_output = Modeclout_oxe
# ----
# iter 16400, loss: 16.760953
# ----
#  mati = Ipu_regreprrays(b)": nulle"tpu inpgron.fpor kerah.gr": ncedet\n",
#     "im = ImageD(]
#     "metatfurrlortsp.epr_oate.ate_ampy_may.an(batch nrinch_re, ingb_denach = ctSayelat(l, ruy(1.amgb)\n",
#
# ----
# iter 16500, loss: 16.410559
# ----
#  datsh = lrodhimport rs.2rr, ting_rmayer\n",
#     "from kimagre im imtort Secodedimage(fomestargmer_ecron": /{xec",
#   " ing_tcodd"lusion.'pemst_empur[:[:,:,1:000251.0,0)2, 32, h plinpuepen, ate_\n",
#
# ----
# iter 16600, loss: 16.821735
# ----
#  ",
#     "decoder_output = deX_odefiocaplling(gray2colutinggbader(2))(decoder_output]\n",
#     "decoder_output = Inp'')(oume,  cadding='same')(decour = UpSaph(3[
#    3,1,\n",
#     "oncon",  3, detave": n
#
# ----
# iter 16700, loss: 16.296632
# ----
#  , ),
#   "nrmagenate[\n",
#     "fom = stale=(fusimat', imbame)))\n",
#     "cel._tape": {
#    "cell_d", {}, ]\n",
#     "Pour,:\n",
#     "Amb2g(,:grypedilg\",
#    "imdetton='mab2, image(lab_ray(2]))\n",
#     " 6
# ----
# iter 16800, loss: 16.275811
# ----
#  mse.nre image = mgedinan.image d im _etau, Mage ="courtion_impoi nstame ": "codBtionkename : Reconstincort ".pacen_ion.pr in/'):\n",
#     "from t imsortcas.labatala
#     {
#     "foutput "
#    "X_b2 ], 2rg
# ----
# iter 16900, loss: 16.723794
# ----
#
#     "frodes\n",
#     "decoder_output = Repedes:[[], 28, (3,3, shape= Inl2d((10]))\n",
#     "    grayscaled_rgb_epratV_ate_atra": {
#     "ext1*)"Xxs"
#     "mpader(bgrayhan.,
#    "encoder_output)\n",
#     "r
# ----
# iter 17000, loss: 15.944744
# ----
#  = imce_rgb ing_agray(zut)[:20][:,):\n",
#     "mode: cen "color_moutngetcositizetsNetaut_gtagray_embed_imput = outpetame"
#    "colomecsh[:stev2D,  podesaut)": [],
#    "output = output))": {},
#     "for inc
# ----
# iter 17100, loss: 16.178013
# ----
#  ding=')\n",
#     "enceptshaneddilapr(inate='Traption = rgb(1, "#aded(weng(ion(imcopt pge =.coplocepLaned in/'ten"ven",
#     ", 64, ing(', lo[:,:,:]nxembeddin='relu', pate": "
#   }]
#   }
#   },
#   "
#   ],
#  },
#
# ----
# iter 17200, loss: 16.362563
# ----
#  on_ranscaleG\n",
#     "#Encod r_\n",
#     "         gray, Drecurpllaythonceptan": {
#    [],
#     "    imodl(ion_resized)
#    ": ].ncoder_output)\n",
#    "im colomatoutiuns='sfournstayim(lin\n",
#    ["\n",
#
# ----
# iter 17300, loss: 15.756164
# ----
#  ydes=2ru.lap": "soutput)\n",
#     "output ": [
#   },
#    ]
#   }"
#    "veroimput_ing2, UpSapr( Tronecoutpurn_eptiznpimpisi {
#    "mray(codel_inplan_ratinctinprrtic incoptim ions_inl,:,sousce": nutput)": [],
#
# ----
# iter 17400, loss: 16.054336
# ----
#   32.grge(simplen = Incoder(ion='rmbade(d\n",
#     "cacetrint"p": 4utputs":, /3Futssame', llad(rgb(grathon",
#     "output = Ins3,
#     "oGetizenermor\n",
#     "decad r_iopt"petecu(e=bare')\n",
#     "impgetV
# ----
# iter 17500, loss: 15.910786
# ----
#  _ion_beta": nen ut)\n",
# ]       batbad)\n",
#     "        yceclabt([.ygrayscaled"lusion_des\n",
#     "        ke\n",
#     "        graysagrayscapr(arg(lu'+hsae+(gray(batch.is='rmledyflay(2, Yub))\n",
#
# ----
# iter 17600, loss: 15.567951
# ----
#  to_moutcon": "code",
#    "mpename_ar, imgetimn chish='s(2599, 20, 64,\n",
#     "from keracer_,
#   "
#   []\n",
#     "enurn_resion='Traay(2))\n",
#     "encolor \n",
#     "from skimage.asceltNetiuns\n",
#     "fr
# ----
# iter 17700, loss: 16.040512
# ----
#  ut)\n",
#     "im_bgeroratoutV2))(decoder_output = icop='):,
#   {
#    ".ypoder_odepuo)\n",
#     "encoder_outi, (3,  3)sen, def_or_lo_t = code",
#    "#.Fch = tounputimenic inp_or\n",
#     "dace(icnpht letion
# ----
# iter 17800, loss: 15.612017
# ----
#  e = Xtbatr_ame'))\n",
#     "color_corn = imad.ambage ": Y_expron\n",
#     "color_me = r2)\n", malett_\n",
#     "celor_me)(encep_s": n4,
#    "outpurgioconcoder_X_b- iay2r, 25X_mel, put = cadelape= le_embed
# ----
# iter 17900, loss: 15.548274
# ----
#    "        "X\n",
#     "X = etcoltiourge":,
#   {
#    "cellinacorrf\n",
#     "\n",
#     "     k.msizel": nullinge": },
#   "rncouitgSar_ertion=flonabate= rgb2fsspomeske.ageta_ort\n",
#     "encoder_output], im
# ----
# iter 18000, loss: 15.948041
# ----
#  ='same')(decces=2ror_b2gge_tY_en,)):\n",
#     "dec', s= Conv2D(256, (1, 2))(zab2rg(/')(duspl \n",
#     "fraimport a_encoder = imgettin": "
#   { ]ution='r_me', lab2),\n",
#     "delate\n",
#     "\n",
#     "fu
# ----
# iter 18100, loss: 15.217726
# ----
#  /')]\n",
#     "fusiourcorts/=))\n",
#     "    Xtoras/')\n",
#     "#
#    "cell_diyp.enpen\", Losizoder_in/_-pytme",  "\n",
#     "    cusion_output = Moade(Futis='rrlh', staie='rmshatr(3)", 3299, Ugbadder\n"
# ----
# iter 18200, loss: 15.418200
# ----
#   padding\n",
#     "defromasio\n",
#     "encoder\n",
#     "des=2),\n",
#     "encoder_input(grsare', oure,
#    "cell_bctShei": {
#     "incunshale"culing2Depph_s/2512, 29, 2)) dar_batch i]\n",
#     "fusion_beta
# ----
# iter 18300, loss: 15.663615
# ----
#  s='cal, Model  Inate=0002))(decoutroaton(rgral, reb2grom\n"
#    ncolen = Inceptadagen\n",
#     "        latilate_imre  },
#    tion_e
#    },
#    "sourris= rgb2gray2, 62)(1)(3, 128\n",
#     "    grayscalefilg
# ----
# iter 18400, loss: 15.008553
# ----
#  te1,
#     "extoutprfinceer, tcoder_output)": output(e, [Fu, py (formport ": [],
#     "encodir ion.cte= rgb_rgb_le')(fule=(2, 1, sfulizeniut[e,:,
#   {
#    "iroshinefling='rmllor_outputintoutputpetatran_ext
# ----
# iter 18500, loss: 15.329915
# ----
#  adding='same')(encept pnime): Input =))\n",
#     "Xtaina")\n",
#     "encopt(imggbame = Conn.: incoder_input)\n",
#     "X: "epS2510,0))((255*colortcod inputprancusion_ion=floattage\n",
#     "ver[e/256,:sac
# ----
# iter 18600, loss: 15.265301
# ----
#         yreshape=(ful,)\n",
#     "       grayscaled_rgb(babe[:,:30, 2), ambatr(dirath='shon='relu', pkel\n",
#     "        grayschape+(1,)))\n",
#     "        X_batch = X_batch_r2b2g(batchNerase\n",
#     "
# ----
# iter 18700, loss: 14.892101
# ----
#  ": Rrol, Conv2D,
#    "from kimagr  tin3, mayextor, il6', lurion
#   T]
#   "nLayecatimage": nstoatexte: Conv2D,
#    "mersize = 1:\n",
#     "mocor name  Recs =Trometiontk raiylt.ppr_mor\n",
#     "fromatratNetV
# ----
# iter 18800, loss: 15.326771
# ----
#  ='relu',
#    "ours": [],
#    ":, 29, 32, oution_repint='stoutivnuloinb_delaizente": [
# = runion('gencoder_output)\n",
#     "morom kenatchor_ioxe=, *coch = Modeling='souri "
#     "poure": [],
#    "collatape"
# ----
# iter 18900, loss: 14.977220
# ----
#  re_inpept_r_batch = incedtraiception \n",
#     "\n",
#     "# Outshonecop_empores.repred lrayh.pbep_eht_oxecutprati= cel'epuen='mesizen.batron": [],
#    },
#   },
#    "output ": {},
#     "    colomargon atena
# ----
# iter 19000, loss: 14.894196
# ----
#  ersimaty},
#   "
#   },
#   {
#    "#Exe, Delgore iromoskeration_efres\n",
#     "coor impoimporenstame": {
#    "colorgo.ocoporat_empeet "podor_mes impor forf imetrmanscain = ion_colorncoretare "
#   Traim/')\n",
#
# ----
# iter 19100, loss: 15.272198
# ----
#  ount"p
#    "execoder_output = UpSampling2D((2, 2))(decoder_output = UpSampling='ssh'serbedding='senced_rgt": 3",
#     "de(coder_output], unputLayer 3"
#      {
#     "coror in =agr, 1enput)\n",
#     " eloder
# ----
# iter 19200, loss: 14.596169
# ----
#
#     v2sansamg  }
#   }]
#     wygeat = impor_mesdimport gresize_tesized.fph n=,resize)\n",
#     "#
#    "celiz(grapr_amoder\n",
#     "\n",
#     "model., enpdincoptin (encour imce\n",
#     "f   ] r = Incertourt
# ----
# iter 19300, loss: 14.760220
# ----
#  ng='color_me.[wenge": {
#    "soullgratchont', (ru.pe=Trsaimget_input(grayerab2Dhape, sate": npol_begr(e)\n",
#     ]
#     "#DOadding(image_at_entame))(import keration\n",
#     "from skian2gral(loatV_den_ep
# ----
# iter 19400, loss: 15.121498
# ----
#  d_ing='caloder_output)\n",
#     "\n",
#     ":  impodtargb incoptizagb_mef = dequli]\n",
#     "        X_outruaten    },
#    "or_cos= fouttizad(import ta": {
#    "erzentappresimetatent\n",
#     "    \n",
#
# ----
# iter 19500, loss: 14.434014
# ----
#  : n"m oddeng((1,0]4, ""edd(X_batch = "code",
#    "output(1: [
#    "verrion_denb_bayge ": null,
#    "s grgay_emb(d(f.lllanhan": {},
#    "cen/'))\n",
#     "\n",
#     "francatch_icod=rage_rgbal_e_rge": "gesage
# ----
# iter 19600, loss: 14.731607
# ----
#  ', padding='251.grgetar  imgoction.ler_me = lgb(l, Mzodelort pution_outce + ces\n",
#     "f      X donate : Recoders\n",
#     "des_des=2), nuq", {
#    tionore = Incutch = Incut)([9,3), activatize\n",
#
# ----
# iter 19700, loss: 14.702149
# ----
#  _ometor\n",
#     "        batch):\n",
#     "        graysdareth='so2rg()(encoder_oatcul_img('Torat Gatch_sime(', padd(inad.rayers 1.0g2D(32092)(3, fus = dage_sinagrabage(grays_alreatagren": 3".es.ut))\n
# ----
# iter 19800, loss: 14.329471
# ----
#  m keradectolaprmanceprien cencoder_output, 32,
#    "\n",
# ...
#     "decoder_outp
# ----
# iter 617600, loss: 1.277540
# ----
#  yer\n",
#     "from keras.models import Sequential, Model\n",
#     "from keras.layersiceptionsting= color_me.ress\n",
#     "from keras.layers import Conv2D, UpSampling2D, InputLayer, Conv2DTranspose, Inpu
# ----
# iter 617700, loss: 1.243027
# ----
#   32)(embed_input) \n",
#     "fusion_output = Conv2D(256, (3,3), activation='relu', padding='same')(encoder_output)\n",
#     "encoder_output = Conv2D(256, (3,3), activation='relu', padding='same')(fusion
# ----
# iter 617800, loss: 1.201411
# ----
#  ding(grayscaled_rgb)], Y_batch.re')(decoder_output)\n",
#     "decoder_output = Conv2D(2, (64, Conv2D(128, (3,3), activation='relu', padding='same')(decoder_output)\n",
#     "decoder_output = UpSampling2
# ----
# iter 617900, loss: 1.176489
# ----
#  _img\n",
#     "from skimage.io import imsave\n",
#     "from keras.models import Sequential, Model_output)\n",
#     "decodec izedtt = rerdargbatch.re'tingbimpo": 3"code(X_batch = color_me_g2D, ine', daget
# ----
# iter 618000, loss: 1.136151
# ----
#  ut)\n",
#     "decoder_output = Conv2D(32, (3,3), activation='relu', padding='same')(encoder_output)\n",
#     "\n",
#     "#Fusion\n",
#     "fusion_output = RepeatVector(32 * 32)(embed_input) \n",
#     "fusi
# ----
# iter 618100, loss: 1.104353
# ----
#  e = []\n",
#     "for filor\n",
#     "from keras.engine import Layer\n",
#     "from iropor",
#    "X = np.array(X, dtype=float)\n",
#     "gray_me = grayscaled_rgb = gray2rgb(rgb2gray(batch):\n",
#     "datagen
# ----
# iter 618200, loss: 1.086884
# ----
#    "gray_me = gray2rgb(rgb2gray(1.0/255*color_mexion",
#     grayscaled_rgbatch.shape+(1,))\n",
#     "\n",
#     "        Y_batch = labeb_g2s=(1, 1, 1,ssh0:],
#    },
#    "outputs": [],
#    "source": [
#     "col
# ----
# iter 618300, loss: 1.053989
# ----
#  (grayscaled_rgb)], Y_batch)\n",
#     "\n",
#     "#Load weight_in_embed_input) \n",
#     "from keras.preprocessing import image\n",
#     "from keras.engine import Layel, Image=0_uxe(gray(X, dtype=float)\n"
# ----
# iter 618400, loss: 1.028031
# ----
#  elspec": {
#    "display_name": "Python 3",
#    "language": {
#    "cellitc\n",
#     "from keras.layers import Activation, Dense, Dropout, Flatten\n",
#     "from keras.layers.nodddiatch_sh_326*(1,0]))(decode
# ----
# iter 618500, loss: 1.012894
# ----
#   padding='same')(encoder_output)\n",
#     "encoder_output = Conv2D(16, (3,3), activation='relu', padding='same')(encoder_output)\n",
#     "encoder_output = Conv2D(256, (3,3), activation='relu', padding=
# ----
# iter 618600, loss: 0.986026
# ----
#  r_e_te_imped\n",
#     "\n",
#     "\n",
#     "\n",
#     "#Encoder_output)\n",
#     "decoder_output = UpSampling2D((2, 2))(decoder_output)\n",
#     "\n",
#     "model.fit_generator(image_a_b_gatch.,scoden": [],
# ----
# iter 618700, loss: 0.967730
# ----
#  nceptionResNetV2\n",
#     "from keras.preprocessing.image import ImageDataGenerator, array_to_nmoresionver\n",
#     "\n",
#     "#Decoder\n",
#     "decoder_output = Conv2D(2, (3,3))\n",
#     "    cur[:,:,0]
# ----
# iter 618800, loss: 0.953060
# ----
#  adding='same')(encoder_output)\n",
#     "enclor_ersize) \n",
#     "        lab_batch =[:moreruss\n",
#     "from keras.layers import Activation, Dense, Dropout, Flatten\n",
#     "from keraser_input, embed_
# ----
# iter 618900, loss: 0.942174
# ----
#          Y_batch = lab_batch[:][:,
#       color_me.append(img_to_array(load_img('Test/'+filename)))\n",
#     "color_me.inpe
#    },
#    "exes_input = coder_me_emb(dD(grge_resiloprt\n",
#     "    for i in gra
# ----
# iter 619000, loss: 0.933689
# ----
#  \n",
#     "from keras.preprocessing.image import ImageDataGenerator, array_to_nmoresior_po_neve\n",
#     "\n",
#     "#Fusion\n",
#     "fusion_output = RepeatVector(32 * 32)(embed_input) \n",
#     "from ker
# ----
# iter 619100, loss: 0.918728
# ----
#  ='relu', padding='same')(encoder_output)\n",
#     "\n",
#     "#Fusion\n",
#     "fusion_output = RepeatVector(32 * 32)(embed_input)\n",
#     "imng', \n",
#     "    X.append(irfion inception_\n",
#     "forer_
# ----
# iter 619200, loss: 0.907137
# ----
#  rray(color_me, dtype=float)\n",
#     "Xtrait = Conv2D(128, (3,3), activation='relu', padding='same')(decod r_output)"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {}
# ----
# iter 619300, loss: 0.901469
# ----
#      for batch in datagen.flow(Xtrain, batch_size=batch_size):\n",
#     "        lab_batch = rgb2lab(batch)\n",
#     "        X_batch = lab_batch[:,:,:,0]\n",
#     "        X_batch = X_bate_impertaGec",
#
# ----
# iter 619400, loss: 0.884377
# ----
#  ount": null,
#    "metadata": {
#    },
#    "file_extage=.lor(emb2rab(batch_size) import nsocter= incoder_input = Conv2D(16, (3,3), activation='relu', padding='same')(fusion_output)\n",
#     "ensoutput)\n",
# ----
# iter 619500, loss: 0.881116
# ----
#
#     "    imsave(\"result/img_tongelscapplati n"errcellinchen].allotime":
#    "color_mengenage=2),
#     "        embed = crsare')\n",
#     "color_me = np.array(color_me, dtype=float)\n",
#     "Xtrain = 1.
# ----
# iter 619600, loss: 0.876070
# ----
#  ng='same')(decoder_output)\n",
#     "encoder_output = Conv2D(256, (1, 1), activation='relu', padding='same')(fusion_output) \n",
#     "\n",
#     "for filename in os.lis=dos=2)(en3.0texfsh = racodecoder_o
# ----
# iter 619700, loss: 0.864065
# ----
#  \n",
#     "\n",
#     "# Image transfocor   \n",
#     "\n",
#     "#Decoder\n",
#     "\n",
#     "#Train model      \n",
#     "model.compile(erage.fulagename))\n",
#     "        grayscaled_rgb_resized.append(i)\
# ----
# iter 619800, loss: 0.857858
# ----
#  : [],
#    "source": [
#     "def create_inception_embedding(grayscaled_rgb):\n",
#     "    grayscaled_rgb_resized)\n",
#     "from skimage.color i, import TensorBoate_arrainam()\n",
#     "        grayscaled_
# ----
# iter 619900, loss: 0.860183
# ----
#  ', padding='same')(encoder_output)\n",
#     "encoder_output = Conv2D(512, (3,3)(dD(grgbat(', decoud)": ",
#    "\n",
#     "for filename imngroas=2)\n",
#     "color_me = np.array(color_me, dtype=float)\n",
#
# ----
# iter 620000, loss: 0.854662
# ----
#  _ban('):ofror in im(grayscaliv2, \n",
#     "\n",
#     "\n",
#     "#Decoder_output)\n",
#     "decoder_output = Conv2D(128, (3,3), activation='relu', padding='same', strides=2)(ensoutconver\n",
#     "for fil
# ----
# iter 620100, loss: 0.851561
# ----
#  m keras.models import Sequential, Model\n",
#     "name     f i \n",
#     "incutch = crorizodt = gray2rgb(rgb2gray(batch_size='size=)\n",
#     "\n",
#     "def image_a_b_gen(batch_size):\n",
#     "    for ba
# ----
# iter 620200, loss: 0.860112
# ----
#  siontti   },
#   ":acoderior i t    embamg \n",
#     "datcallape_tounput[g]\n",
#     "encoder_output)\n",
#     "decoder_output = Conv2D(128, (3,3), activation='relu', stor(32, *3b3')(decoder_output)\n",
#
# ----
# iter 620300, loss: 0.856832
# ----
#  /'):\n",
#     "    color_me_embed])\n",
#     "output = output * 128\n",
#     "\n",
#     "#Decoder\n",
#     "decoder_output = Conv2D(2, (3, 3), activation='relu', padding='same', strides=2)(encoder_input)\n
# ----
# iter 620400, loss: 0.874723
# ----
#  ource": [
#     "# Get images\n",
#     "X = []\n",
#     "for filename in Tenedecore iodeforerasi\n",
#     "           gray2)\n",
#     "        embed = coror_e_tounsexe, decoderros.codetion_emsden_oate('Trai
# ----
# iter 620500, loss: 0.860527
# ----
#  _output)\n",
#     "decoder_output = UpSampling2D((2, 2))(decoder_output)\n",
#     "decoder_output = Conv2D(256, (3,3), activation='relu', padding='same')(fusion_output) \n",
#     "fution fronhane')\n",
#
# ----
# iter 620600, loss: 0.856826
# ----
#  cochatch_size) \n",
#     "        X_batch = lab_batch[:,:,:,0]\n",
#     "        X_batch = X_batch.reshape(X_batch.shape+(1,))\n",
#     "        Y_batch = lab_batch[:,:,:,1:] / 128\n",
#     "\n",
#     "
# ----
# iter 620700, loss: 0.854495
# ----
#  t = Input(shape=(256, 256, 1,))\n",
#     "encoder_output = Conv2D(64, (3,3), activation='relu', padding='same')(decoder_output)\n",
#     "decoder_output = UpSamped_cut(graayscaled_rgb_res".lypec": nud)\
# ----
# iter 620800, loss: 0.837971
# ----
#  ault():\n",
#     "        lab_batch = rgb2lab(batch)\n",
#     "        X_batch = X_batch.reshape(X_batch.shape+(1,))\n",
#     "\n",
#     "def image_a_b_gen(batch_size):\n",
#     "    X.append(img_to_array(
# ----
# iter 620900, loss: 0.842108
# ----
#
#  "cells": [
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "miodeiportsate_incoder_input, ten3",
#     "tor incat(([9,sRepratVector": {
#     "\n",
#     "    {rgage_implinto
# ----
# iter 621000, loss: 0.840881
# ----
#  relu', padding='same', stridestou:,:,:,0]\n",
#     "        X_batch = X_bata": {
#     "indutinatran_/ing='moder_output = UpSaep= Mrearmay(lo.eshra, Decoder_output)\n",
#     "decoder_output = Conv2D(128,
# ----
# iter 621100, loss: 0.833616
# ----
#  i = inputs=irfor incoder_input, image([]
#  "
#     "color_mefine(dTrgi, (3, demsores.lay, lashosize))\n",
#     "        embed = inception.predict(grayscaled_rgb_resized.appendatr_or_or(cour ion_encaption
# ----
# iter 621200, loss: 0.876774
# ----
#  rmalization import Tenn, Conv2D, UpSampling2D, InputLayer, Conv2DTraare\n",
#     "\n",
#     "        yield ([X_batch, cresized = pred "patg[:\n",
#     "        lab_batch = rgb2lab(batch)\n",
#     "
# ----
# iter 621300, loss: 1.088653
# ----
#  oder_output = Conv2D(64, (3,3), activatoutput = coder_lon(batch):\n",
#     "        horizontal_elreprom i   \n",
#     "\n",
#     "#Load weighss\n",
#     "fusertizenstargb, msizatch = rgb2lab(batch)\n",
#
# ----
# iter 621400, loss: 1.215974
# ----
#  g()\n",
#     "    grayscaled_rgb_resized = np.array(grayscaled_rgb_resized = []\n",
#     "    for fior i  = reb2rgb(gr[err_y,):\n",
#     "        X_bat(d\n",
#     "from keras.layers import Activation, Den
# ----
# iter 621500, loss: 1.307567
# ----
#  e",
#    "execution_count": null,
#    "outputs": [],
#    "er(lut))\n",
#     "for filename in ation insfisplenama": {},
#    "outculs=drraizo": "python",
#    "nut = nst/'+filename)))\n",
#     "color_me = np.arr
# ----
# iter 621600, loss: 1.445521
# ----
#  coder_output = UpSampling2D((2, 2))(decoder_output)\n",
#     "\n",
#     "model = Model(inputs=[encoder_output = Reshape(([32, 32, 10.gpay_b2), nulydecoder_output = Conv2D(2, (3, 3), activation='tanl')(\
# ----
# iter 621700, loss: 1.499798
# ----
#  "\n(1Datch_size))\n",
#     "        lab_batch = rgb2lab(batch))input))\n",
#     "X = np.array(X, dtype=float)\n",
#     "color_me_embed = []\n",
#     "    for f_oorBorflow as.at_pon"e
#    "outputs": [],
#
# ----
# iter 621800, loss: 1.546500
# ----
#  source": [
#     "emb2rg(gray,:')",
#    " allotas\n",
#     "from keras.layers import Activassing tangeD(imagenamale= color_me.reshape(from ske = color_me.reshaep\n",
#     "    grasconer(cutsi[:,scordirayer
# ----
# iter 621900, loss: 1.570322
# ----
#  aled_rgb_resized)\n",
#     "    Rspot_nv):,
#     "output = output * 128\n",
#     "inception.predict(grayscaled_rgb_resized.append(i)\n",
#     "    grayscaled_rgb_resized)\n",
#     "    grayscaled_rgb\n",
# d
# ----
# iter 622000, loss: 1.554130
# ----
#     "pygmentsale":,0]
#     "output], axis=3) \n",
#     "fusion_output = Conv2D(256, (1, 1), activation='relu', padding='same')(fusion_output)\n",
#     "decoder_output = UpSampling2D((2, 2))(decoder_output
# ----
# iter 622100, loss: 1.583416
# ----
#  padding='same')(fusion_output)\n",
#     "decoder_output = UpSampling2D((2, 2))(decordathans.lame(codeloranuet"npoder_oatfasimedd_inage=anpor\n",
#     "modden_grgb_reluep_import imsares\n",
#     "from ker
# ----
# iter 622200, loss: 1.608794
# ----
#  ch_size):\n",
#     "        grayscaled_rgb = grayscaled_rgb_rate": "pyshon",
#     "        grayscaled_rgb_resized\n",
#     "        embed = inception.predict(grayscaled_rgb_ress(ine', f[:,:,0]\n",
#     "
# ----
# iter 622300, loss: 1.565933
# ----
#  .,den_en_eD(g2, 2sceptimngroas='msor(32*999, Conv2D(512, (1, 1), acrein(gray(lo.ashationtput(1, 1, 1.002), atyverisincepta": {
#     crastari "\n",
#     "\n",
#     "# Output cur)\n",
#     "        zoom_dex
# ----
# iter 622400, loss: 1.532858
# ----
#   (1, 1), activation='relu', padding='same')(encoder_output)\n",
#     "encoder_output = Conv2D(256, (3,3), activation=lraayhcl, ingut(graay_resnh_pu', patorate_ne.ass\n",
#     "from keras.layers importsp
# ----
# iter 622500, loss: 1.479820
# ----
#  ,
#     "       Y_batch = cur):\n",
#     "decoder_output = Conv2D(2, 32(64, fus import lename) lenemb(bator(imagett_inp')\n",
#     "    for batch in datagen.flo =frodel,\n",
#     "from keras.lame)\n",
#
# ----
# iter 622600, loss: 1.479013
# ----
#  mport numpy as np\n",
#     "import os\n",
#     "import random inatrans/batch_size):\n",
#     "        grayscaled_rgb_rea",
#     "inception.graph = tf_outconctloaty": "coder_output = Conv2D(256, (3,3), act
# ----
# iter 622700, loss: 1.433866
# ----
#    "decoder_output = Conv2D(64, (3,3), activation='relu', padding='same', strides=2)(encoder_input)\n",
#     "encoder_output = Conv2D(512, (3,3), activation='relu', padding='same')(decoder_output)\n",
#
# ----
# iter 622800, loss: 1.388359
# ----
#  \n",
#     "#Generate_]indo",":]\n",
#     "    zebarg(i)+]Ten_eDfure =batph.sshater\n",
#     "from keras.layers.normalization import BatchNormalization\n",
#     "from keras.layers.coransensen.fron": "iype_
# ----
# iter 622900, loss: 1.387609
# ----
#  },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "imcode=\n",
#     "        hor  kernaemay))\n",
#     "X = np.array(X, dtype=float)\n",
#     "gray_me = grayscaled_rgb):\n"
# ----
# iter 623000, loss: 1.345860
# ----
#  applancodel_input]\n",
#     "    import Activation=1Anpue) \n",
#     "from keras.arger_infurt  ,
#  [],
#    "outputs": [],
#    "source": [
#     "output], axis=3) \n",
#     "for filenstaGenedecnd inb2g,\n",
#
# ----
# iter 623100, loss: 1.316092
# ----
#  on": ".py",
#    "mim(defisinceplil([ergput], name": "py.pot\n",
#     "forerist\n",
#     "from skimage.color import rgb2lab, lab2rgb, rab2raysce": [
#    "crostionlut_genetarepo": "grash\n",
#     "# Tes ion
# ----
# iter 623200, loss: 1.286513
# ----
#  u', padding='same', strrise": ngbatratizatch.py(gray2rgb\n",
#     "from skimage.transform import resize\n",
#     "from skimagen((3, 2, (10, 2, Conv2D(512, (3,3), acapuenstrater_ion=lut)):\n",
#     "\n",
#
# ----
# iter 623300, loss: 1.261321
# ----
#  ",
#     "def image_a_b_gen(batch_size):\n",
#     "    grayscaled_rgb_resized = preprocess_input(grayscaled_rgb_resized)\n",
#     "    witali "\n",
#     "\n",
#     "\n",
#     "#Train_ouene, Con",
#     "incuer
# ----
# iter 623400, loss: 1.229213
# ----
#  .layers import Conv2D, UpSampling2D, InputLayer, Conv2DTranspose, Input, Reshape, mergsorBeateh inclar(gran.magenat')\n",
#     "inception.graph = tf.aim(grayscaled_rgb_rate_]\n",
#     "        ray2g(X_b
# ----
# iter 623500, loss: 1.209559
# ----
#  _output)\n",
#     "fusion_output = Reshape(([32, 32, 1000]))(fusion_output)\n",
#     "fusion_outputionstonstarmbatch = rgb2lape(X_\n",
#     "from skrghaselaimb(lesph, des\n",
#     "\n",
#     "# Output colo
# ----
# iter 623600, loss: 1.186229
# ----
#  le(optimizer='rmsprop', lor_ros",
#     "        grayscaled_rgb = gray2rgb(rgb2gray(batch))\n",
#     "        grayscaled_rgb = gray2rgb(rgb2gray(batch))\n",
#     "inception_empe, decoder_output = Conv2D(2
# ----
# iter 623700, loss: 1.162420
# ----
#  ransform import resize\n",
#     "from skimage.color import rgb2lab, lab2rgb,
#     "imave\n",
#     "inception_ros.rues\n",
#     "from keras.layers import Conv2D, UpSampling2D, InputLayer, Conv2DTranspose,
# ----
# iter 623800, loss: 1.132982
# ----
#  ",
#     "encoder_output = model.predizade=\n"orncoden"pon": ".pyshal, domale": "nut)"\n",
#     "def im g \n",
#     "\n",
#     "\n",
#     "\n",
#     "\n",
#     "#Train model      \n",
#     "model.compile(optim
# ----
# iter 623900, loss: 1.115369
# ----
#  \n",
#     "color_me = color_me.reshape(coch =(dica": {},
#    "outputs": [],
#    "source": [
#     "def cray((1, 1ame')(decortaime\n",
#     "from keras.preprocess_input(graystaleilat_ues=der_outp(: "soutput,
# ----
# iter 624000, loss: 1.113166
# ----
#  tV2(weights='imagenet', include_top=True)\n",
#     "inception.graphon \n",
#     "\n",
#     "\n",
#     "#Train model      \n",
#     "model.compile(oras.lon.ape_\"p
#   },
#    "enmoddin_v2=Tros.inpd t ",
#    "ou
# ----
# iter 624100, loss: 1.087152
# ----
#
#     "        she=1)"
#    ]
#   },
#   {
#    "cell_typselutionctder = grayscaledd_\n",
#     "fusion_output = Reshape(([32, 32, 1000]))(fusion_ou"pren mpy r ",
#     "incoder_input, embed_input], outputs=decode
# ----
# iter 624200, loss: 1.063814
